# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import layers, models
import geopandas as gpd
import ast
import os
import json

# 1. Inspect and Load GeoJSON Files
data_dir = "/kaggle/input/treesatai-indices"  # Path to new data
all_features = []
all_labels = []
invalid_samples = []

# Updated list of bands based on inspection
bands = ['ARVI', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'DEM', 'EVI', 'EVI2', 'NDVI', 'NDWI']
months = ['', '_1', '_2', '_3', '_4', '_5', '_6', '_7']
band_columns = [band + month for month in months for band in bands]  # 18 bands × 8 months = 144 channels

# Inspect first file for debugging
first_file = os.path.join(data_dir, os.listdir(data_dir)[0]) if os.listdir(data_dir) else None
if first_file and first_file.endswith(".geojson"):
    gdf = gpd.read_file(first_file)
    print("Inspecting first 2 rows of first GeoJSON file:")
    for idx in range(min(2, len(gdf))):
        print(f"\nRow {idx}:")
        for band in ['ARVI', 'B1', 'B11', 'NDVI', 'B2_1', 'NDVI_7']:  # Sample of new and old bands
            data = gdf[band].iloc[idx]
            print(f"  Band {band}: type={type(data)}, raw_value={str(data)[:100]}...")
            try:
                if isinstance(data, (list, np.ndarray)):
                    array = np.array(data, dtype=np.float32)
                elif isinstance(data, str):
                    try:
                        array = np.array(json.loads(data), dtype=np.float32)
                    except json.JSONDecodeError:
                        array = np.array(ast.literal_eval(data), dtype=np.float32)
                elif isinstance(data, (float, np.float32, np.float64)):
                    array = np.full((5, 5), data, dtype=np.float32)
                else:
                    raise ValueError(f"Unexpected data type for band {band}: {type(data)}")
                if array.shape != (5, 5):
                    raise ValueError(f"Band {band} has shape {array.shape}, expects (5, 5)")
                print(f"  Band {band}: shape={array.shape}, first few values={array.flatten()[:5]}")
            except Exception as e:
                print(f"  Band {band}: Error processing data: {e}")

# Load all GeoJSON files
for file in os.listdir(data_dir):
    if file.endswith(".geojson"):
        gdf = gpd.read_file(os.path.join(data_dir, file))
        for idx, row in gdf.iterrows():
            try:
                patches = []
                for col in band_columns:
                    if col not in gdf.columns:
                        raise ValueError(f"Column {col} not found in {file}")
                    val = row[col]
                    if isinstance(val, (list, np.ndarray)):
                        arr = np.array(val, dtype=np.float32).reshape(5, 5)
                    elif isinstance(val, str):
                        try:
                            arr = np.array(json.loads(val), dtype=np.float32).reshape(5, 5)
                        except json.JSONDecodeError:
                            arr = np.array(ast.literal_eval(val), dtype=np.float32).reshape(5, 5)
                    elif isinstance(val, (float, np.float32, np.float64)):
                        arr = np.full((5, 5), val, dtype=np.float32)
                    else:
                        raise ValueError(f"Unexpected data type for band {col}: {type(val)}")
                    patches.append(arr)

                patch = np.stack(patches, axis=-1)
                if patch.shape != (5, 5, 144):  # Updated to 18 bands × 8 months = 144 channels
                    raise ValueError(f"Unexpected patch shape: {patch.shape}, expected (5, 5, 144)")
                all_features.append(patch)
                all_labels.append(row['l3_species'])
            except Exception as e:
                invalid_samples.append((file, idx, str(e)))
                continue

# Log invalid samples
if invalid_samples:
    print(f"\nSkipped {len(invalid_samples)} invalid samples:")
    for file, idx, error in invalid_samples[:5]:
        print(f"File: {file}, Row: {idx}, Error: {error}")
    if invalid_samples:
        print(f"First invalid sample raw data (ARVI): {str(gdf.iloc[invalid_samples[0][1]]['ARVI'])[:100]}...")

# Convert to NumPy arrays
if not all_features:
    raise ValueError("No valid samples loaded. Check GeoJSON files or GEE export.")
X = np.array(all_features, dtype=np.float32)  # Shape: (num_samples, 5, 5, 144)
y = np.array(all_labels)

print(f"Loaded {len(all_features)} valid samples with shape {X.shape}")
# Out:
# 2025-06-26 08:59:54.691945: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750928394.876593      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750928394.927823      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Inspecting first 2 rows of first GeoJSON file:
#
# Row 0:
#   Band ARVI: type=<class 'numpy.float64'>, raw_value=0.41744154691696167...
#   Band ARVI: shape=(5, 5), first few values=[0.41744155 0.41744155 0.41744155 0.41744155 0.41744155]
#   Band B1: type=<class 'numpy.float64'>, raw_value=0.12300000339746475...
#   Band B1: shape=(5, 5), first few values=[0.123 0.123 0.123 0.123 0.123]
#   Band B11: type=<class 'numpy.float64'>, raw_value=0.18479999899864197...
#   Band B11: shape=(5, 5), first few values=[0.1848 0.1848 0.1848 0.1848 0.1848]
#   Band NDVI: type=<class 'numpy.float64'>, raw_value=0.42132997512817383...
#   Band NDVI: shape=(5, 5), first few values=[0.42132998 0.42132998 0.42132998 0.42132998 0.42132998]
#   Band B2_1: type=<class 'numpy.float64'>, raw_value=0.11259999871253967...
#   Band B2_1: shape=(5, 5), first few values=[0.1126 0.1126 0.1126 0.1126 0.1126]
#   Band NDVI_7: type=<class 'numpy.float64'>, raw_value=0.3798370659351349...
#   Band NDVI_7: shape=(5, 5), first few values=[0.37983707 0.37983707 0.37983707 0.37983707 0.37983707]
#
# Row 1:
#   Band ARVI: type=<class 'numpy.float64'>, raw_value=0.16849634051322937...
#   Band ARVI: shape=(5, 5), first few values=[0.16849634 0.16849634 0.16849634 0.16849634 0.16849634]
#   Band B1: type=<class 'numpy.float64'>, raw_value=0.14994999766349792...
#   Band B1: shape=(5, 5), first few values=[0.14995 0.14995 0.14995 0.14995 0.14995]
#   Band B11: type=<class 'numpy.float64'>, raw_value=0.38510000705718994...
#   Band B11: shape=(5, 5), first few values=[0.3851 0.3851 0.3851 0.3851 0.3851]
#   Band NDVI: type=<class 'numpy.float64'>, raw_value=0.2599557340145111...
#   Band NDVI: shape=(5, 5), first few values=[0.25995573 0.25995573 0.25995573 0.25995573 0.25995573]
#   Band B2_1: type=<class 'numpy.float64'>, raw_value=0.15575000643730164...
#   Band B2_1: shape=(5, 5), first few values=[0.15575 0.15575 0.15575 0.15575 0.15575]
#   Band NDVI_7: type=<class 'numpy.float64'>, raw_value=0.3259807527065277...
#   Band NDVI_7: shape=(5, 5), first few values=[0.32598075 0.32598075 0.32598075 0.32598075 0.32598075]
#
# Skipped 5199 invalid samples:
# File: needleleaf_pine_weymouth pine.geojson, Row: 57, Error: Unexpected data type for band ARVI_4: <class 'NoneType'>
# File: needleleaf_pine_weymouth pine.geojson, Row: 84, Error: Unexpected data type for band ARVI_4: <class 'NoneType'>
# File: needleleaf_pine_weymouth pine.geojson, Row: 97, Error: Unexpected data type for band ARVI_4: <class 'NoneType'>
# File: needleleaf_pine_weymouth pine.geojson, Row: 125, Error: Unexpected data type for band ARVI_4: <class 'NoneType'>
# File: needleleaf_pine_weymouth pine.geojson, Row: 139, Error: Unexpected data type for band ARVI_1: <class 'NoneType'>
# First invalid sample raw data (ARVI): 0.18817108869552612...
# Loaded 32708 valid samples with shape (32708, 5, 5, 144)

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import layers, models
import geopandas as gpd
import os
import json
import joblib
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt


# 2. Handle NaN Values
print("\nChecking for NaN values...")
nan_mask = np.any(np.isnan(X), axis=(1, 2, 3))
nan_count = np.sum(nan_mask)
print(f"Found {nan_count} samples with NaN values")
if nan_count > 0:
    print(f"Removing {nan_count} samples with NaN values")
    valid_mask = ~nan_mask
    X = X[valid_mask]
    y = y[valid_mask]
    print(f"New data shape after removing NaN: {X.shape}")

# 3. Normalize Data
print("\nNormalizing data...")
X_min = np.nanmin(X, axis=(0, 1, 2), keepdims=True)
X_max = np.nanmax(X, axis=(0, 1, 2), keepdims=True)
X = (X - X_min) / (X_max - X_min + 1e-6)  # Min-max normalization to [0, 1]
print(f"Data range after normalization: min={np.nanmin(X):.4f}, max={np.nanmax(X):.4f}")

# 4. Preprocess Labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
y_onehot = tf.keras.utils.to_categorical(y_encoded)
num_classes = len(label_encoder.classes_)
print(f"\nData shape: {X.shape}, Number of classes: {num_classes}")

# 5. Define Feature Combinations
spectral_bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12']  # 12 bands
veg_indices = ['ARVI', 'EVI', 'EVI2', 'NDVI', 'NDWI', 'RENDVI', 'SAVI', 'NBR']  # 8 bands
dem_band = ['DEM']  # 1 band

# Create and verify channel indices
spectral_indices = [i for i, col in enumerate(band_columns) if any(col.startswith(band) for band in spectral_bands)]
veg_indices_indices = [i for i, col in enumerate(band_columns) if any(col.startswith(band) for band in veg_indices)]
dem_indices = [i for i, col in enumerate(band_columns) if col.startswith('DEM')]

# Debug channel indices
print("\nDebugging channel indices:")
print(f"Spectral indices ({len(spectral_indices)}): {[band_columns[i] for i in spectral_indices]}")
print(f"Vegetation indices ({len(veg_indices_indices)}): {[band_columns[i] for i in veg_indices_indices]}")
print(f"DEM indices ({len(dem_indices)}): {[band_columns[i] for i in dem_indices]}")
print(f"Spectral + Veg indices ({len(spectral_indices + veg_indices_indices)}): {[band_columns[i] for i in spectral_indices + veg_indices_indices]}")

# Verify expected channel counts
expected_veg_channels = 8 * len(months)  # 8 bands × 8 months
if len(veg_indices_indices) != expected_veg_channels:
    print(f"Warning: Expected {expected_veg_channels} vegetation indices channels, got {len(veg_indices_indices)}")
    missing_veg_bands = [band for band in veg_indices if not any(col.startswith(band) for col in band_columns)]
    print(f"Missing vegetation indices: {missing_veg_bands}")

feature_combinations = {
    'spectral': (spectral_indices, 96, 'Spectral Bands Only'),
    'spectral_veg': (spectral_indices + veg_indices_indices, 96 + len(veg_indices_indices), 'Spectral + Vegetation Indices'),
    'spectral_dem': (spectral_indices + dem_indices, 96 + 8, 'Spectral + DEM'),
    'all_features': (list(range(144)), 144, 'Spectral + Vegetation Indices + DEM')
}

# 6. Define CNN Model
def build_cnn(input_shape, num_classes):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

# 7. Data Augmentation
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
])

# 8. Train and Evaluate for Each Feature Combination
results = {}
for combo_name, (indices, num_channels, description) in feature_combinations.items():
    print(f"\nTraining model with {description} ({num_channels} channels)")
    
    # Select feature subset
    X_subset = X[:, :, :, indices]
    print(f"Subset shape: {X_subset.shape}")
    
    # Verify no NaN in subset
    if np.any(np.isnan(X_subset)):
        print(f"Warning: NaN values found in {description} subset")
    
    # Train-test-validation split
    X_train, X_test, y_train, y_test = train_test_split(X_subset, y_onehot, test_size=0.15, random_state=42, stratify=y_onehot)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1765, random_state=42, stratify=y_train)
    
    # Build and compile model
    model = build_cnn(input_shape=(5, 5, num_channels), num_classes=num_classes)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train model
    history = model.fit(
        data_augmentation(X_train), y_train,
        validation_data=(X_val, y_val),
        epochs=50,
        batch_size=32,
        callbacks=[
            tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
            tf.keras.callbacks.ModelCheckpoint(f'best_model_{combo_name}.keras', save_best_only=True)
        ],
        verbose=1
    )
    
    # Evaluate model
    test_loss, test_accuracy = model.evaluate(X_test, y_test)
    print(f"{description} Test Accuracy: {test_accuracy:.4f}")
    
    # Confusion matrix
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_test_classes = np.argmax(y_test, axis=1)
    cm = confusion_matrix(y_test_classes, y_pred_classes)
    
    # Plot confusion matrix
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title(f'Confusion Matrix: {description}')
    plt.savefig(f'confusion_matrix_{combo_name}.png')
    plt.close()
    
    # Store results
    results[combo_name] = {
        'description': description,
        'test_accuracy': test_accuracy,
        'test_loss': test_loss,
        'history': history.history
    }

# 9. Compare Results
print("\nSummary of Results:")
for combo_name, result in results.items():
    print(f"{result['description']}: Test Accuracy = {result['test_accuracy']:.4f}, Test Loss = {result['test_loss']:.4f}")

# Plot accuracy comparison
plt.figure(figsize=(10, 6))
accuracies = [results[combo]['test_accuracy'] for combo in results]
combo_names = [results[combo]['description'] for combo in results]
plt.bar(combo_names, accuracies)
plt.xlabel('Feature Combination')
plt.ylabel('Test Accuracy')
plt.title('Test Accuracy by Feature Combination')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('accuracy_comparison.png')
plt.close()

# 10. Save Label Encoder and Results
joblib.dump(label_encoder, 'label_encoder.pkl')
with open('results_summary.json', 'w') as f:
    json.dump({k: {kk: vv for kk, vv in v.items() if kk != 'history'} for k, v in results.items()}, f, indent=4)
# Out:
# Checking for NaN values...
# Found 6440 samples with NaN values
# Removing 6440 samples with NaN values
# New data shape after removing NaN: (26268, 5, 5, 144)
#
# Normalizing data...
# Data range after normalization: min=0.0000, max=1.0000
#
# Data shape: (26268, 5, 5, 144), Number of classes: 19
#
# Debugging channel indices:
# Spectral indices (96): ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'B1_1', 'B2_1', 'B3_1', 'B4_1', 'B5_1', 'B6_1', 'B7_1', 'B8_1', 'B8A_1', 'B9_1', 'B11_1', 'B12_1', 'B1_2', 'B2_2', 'B3_2', 'B4_2', 'B5_2', 'B6_2', 'B7_2', 'B8_2', 'B8A_2', 'B9_2', 'B11_2', 'B12_2', 'B1_3', 'B2_3', 'B3_3', 'B4_3', 'B5_3', 'B6_3', 'B7_3', 'B8_3', 'B8A_3', 'B9_3', 'B11_3', 'B12_3', 'B1_4', 'B2_4', 'B3_4', 'B4_4', 'B5_4', 'B6_4', 'B7_4', 'B8_4', 'B8A_4', 'B9_4', 'B11_4', 'B12_4', 'B1_5', 'B2_5', 'B3_5', 'B4_5', 'B5_5', 'B6_5', 'B7_5', 'B8_5', 'B8A_5', 'B9_5', 'B11_5', 'B12_5', 'B1_6', 'B2_6', 'B3_6', 'B4_6', 'B5_6', 'B6_6', 'B7_6', 'B8_6', 'B8A_6', 'B9_6', 'B11_6', 'B12_6', 'B1_7', 'B2_7', 'B3_7', 'B4_7', 'B5_7', 'B6_7', 'B7_7', 'B8_7', 'B8A_7', 'B9_7', 'B11_7', 'B12_7']
# Vegetation indices (40): ['ARVI', 'EVI', 'EVI2', 'NDVI', 'NDWI', 'ARVI_1', 'EVI_1', 'EVI2_1', 'NDVI_1', 'NDWI_1', 'ARVI_2', 'EVI_2', 'EVI2_2', 'NDVI_2', 'NDWI_2', 'ARVI_3', 'EVI_3', 'EVI2_3', 'NDVI_3', 'NDWI_3', 'ARVI_4', 'EVI_4', 'EVI2_4', 'NDVI_4', 'NDWI_4', 'ARVI_5', 'EVI_5', 'EVI2_5', 'NDVI_5', 'NDWI_5', 'ARVI_6', 'EVI_6', 'EVI2_6', 'NDVI_6', 'NDWI_6', 'ARVI_7', 'EVI_7', 'EVI2_7', 'NDVI_7', 'NDWI_7']
# DEM indices (8): ['DEM', 'DEM_1', 'DEM_2', 'DEM_3', 'DEM_4', 'DEM_5', 'DEM_6', 'DEM_7']
# Spectral + Veg indices (136): ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'B1_1', 'B2_1', 'B3_1', 'B4_1', 'B5_1', 'B6_1', 'B7_1', 'B8_1', 'B8A_1', 'B9_1', 'B11_1', 'B12_1', 'B1_2', 'B2_2', 'B3_2', 'B4_2', 'B5_2', 'B6_2', 'B7_2', 'B8_2', 'B8A_2', 'B9_2', 'B11_2', 'B12_2', 'B1_3', 'B2_3', 'B3_3', 'B4_3', 'B5_3', 'B6_3', 'B7_3', 'B8_3', 'B8A_3', 'B9_3', 'B11_3', 'B12_3', 'B1_4', 'B2_4', 'B3_4', 'B4_4', 'B5_4', 'B6_4', 'B7_4', 'B8_4', 'B8A_4', 'B9_4', 'B11_4', 'B12_4', 'B1_5', 'B2_5', 'B3_5', 'B4_5', 'B5_5', 'B6_5', 'B7_5', 'B8_5', 'B8A_5', 'B9_5', 'B11_5', 'B12_5', 'B1_6', 'B2_6', 'B3_6', 'B4_6', 'B5_6', 'B6_6', 'B7_6', 'B8_6', 'B8A_6', 'B9_6', 'B11_6', 'B12_6', 'B1_7', 'B2_7', 'B3_7', 'B4_7', 'B5_7', 'B6_7', 'B7_7', 'B8_7', 'B8A_7', 'B9_7', 'B11_7', 'B12_7', 'ARVI', 'EVI', 'EVI2', 'NDVI', 'NDWI', 'ARVI_1', 'EVI_1', 'EVI2_1', 'NDVI_1', 'NDWI_1', 'ARVI_2', 'EVI_2', 'EVI2_2', 'NDVI_2', 'NDWI_2', 'ARVI_3', 'EVI_3', 'EVI2_3', 'NDVI_3', 'NDWI_3', 'ARVI_4', 'EVI_4', 'EVI2_4', 'NDVI_4', 'NDWI_4', 'ARVI_5', 'EVI_5', 'EVI2_5', 'NDVI_5', 'NDWI_5', 'ARVI_6', 'EVI_6', 'EVI2_6', 'NDVI_6', 'NDWI_6', 'ARVI_7', 'EVI_7', 'EVI2_7', 'NDVI_7', 'NDWI_7']
# Warning: Expected 64 vegetation indices channels, got 40
# Missing vegetation indices: ['RENDVI', 'SAVI', 'NBR']
# I0000 00:00:1750928691.687280      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Training model with Spectral Bands Only (96 channels)
# Subset shape: (26268, 5, 5, 96)
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1750928699.518656      59 service.cc:148] XLA service 0x784c94012e90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1750928699.519171      59 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1750928699.934266      59 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  54/575 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1877 - loss: 2.9053
# I0000 00:00:1750928702.663614      59 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.3186 - loss: 2.2618 - val_accuracy: 0.1342 - val_loss: 6.5486
# Epoch 2/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4806 - loss: 1.6972 - val_accuracy: 0.3905 - val_loss: 1.9868
# Epoch 3/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5280 - loss: 1.5624 - val_accuracy: 0.3367 - val_loss: 2.4204
# Epoch 4/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5612 - loss: 1.4455 - val_accuracy: 0.3608 - val_loss: 2.5333
# Epoch 5/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5628 - loss: 1.4279 - val_accuracy: 0.4017 - val_loss: 2.0715
# Epoch 6/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5910 - loss: 1.3331 - val_accuracy: 0.5633 - val_loss: 1.3933
# Epoch 7/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5921 - loss: 1.2959 - val_accuracy: 0.3476 - val_loss: 2.5993
# Epoch 8/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6089 - loss: 1.2775 - val_accuracy: 0.4631 - val_loss: 2.0632
# Epoch 9/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6347 - loss: 1.1981 - val_accuracy: 0.5585 - val_loss: 1.5622
# Epoch 10/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6546 - loss: 1.1062 - val_accuracy: 0.2900 - val_loss: 2.7187
# Epoch 11/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6742 - loss: 1.0386 - val_accuracy: 0.6498 - val_loss: 1.0686
# Epoch 12/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7034 - loss: 0.9449 - val_accuracy: 0.7120 - val_loss: 0.8686
# Epoch 13/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7104 - loss: 0.9035 - val_accuracy: 0.5884 - val_loss: 1.2205
# Epoch 14/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7202 - loss: 0.8780 - val_accuracy: 0.5389 - val_loss: 1.5030
# Epoch 15/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7206 - loss: 0.8574 - val_accuracy: 0.4423 - val_loss: 2.0719
# Epoch 16/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7207 - loss: 0.8607 - val_accuracy: 0.5131 - val_loss: 1.9371
# Epoch 17/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7400 - loss: 0.7911 - val_accuracy: 0.4067 - val_loss: 2.6957
# Epoch 18/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7405 - loss: 0.7734 - val_accuracy: 0.5095 - val_loss: 1.7066
# Epoch 19/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7486 - loss: 0.7672 - val_accuracy: 0.6354 - val_loss: 1.1533
# Epoch 20/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7480 - loss: 0.7638 - val_accuracy: 0.5065 - val_loss: 1.7620
# Epoch 21/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7485 - loss: 0.7495 - val_accuracy: 0.6717 - val_loss: 0.9610
# Epoch 22/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7596 - loss: 0.7272 - val_accuracy: 0.6356 - val_loss: 1.2401
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7135 - loss: 0.8724
# Spectral Bands Only Test Accuracy: 0.7176
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#
# Training model with Spectral + Vegetation Indices (136 channels)
# Subset shape: (26268, 5, 5, 136)
# Epoch 1/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.3102 - loss: 2.2662 - val_accuracy: 0.2888 - val_loss: 2.8822
# Epoch 2/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4727 - loss: 1.7183 - val_accuracy: 0.1972 - val_loss: 7.5013
# Epoch 3/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5209 - loss: 1.5672 - val_accuracy: 0.3588 - val_loss: 3.2319
# Epoch 4/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5547 - loss: 1.4821 - val_accuracy: 0.2522 - val_loss: 4.1924
# Epoch 5/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5716 - loss: 1.4148 - val_accuracy: 0.5255 - val_loss: 1.6288
# Epoch 6/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5845 - loss: 1.3718 - val_accuracy: 0.4753 - val_loss: 1.8053
# Epoch 7/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5996 - loss: 1.3056 - val_accuracy: 0.3768 - val_loss: 2.2076
# Epoch 8/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6204 - loss: 1.2296 - val_accuracy: 0.5354 - val_loss: 1.5736
# Epoch 9/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6595 - loss: 1.0943 - val_accuracy: 0.5516 - val_loss: 1.4704
# Epoch 10/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6770 - loss: 1.0159 - val_accuracy: 0.3793 - val_loss: 2.5038
# Epoch 11/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7007 - loss: 0.9421 - val_accuracy: 0.4572 - val_loss: 1.9995
# Epoch 12/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7124 - loss: 0.8722 - val_accuracy: 0.5402 - val_loss: 1.3855
# Epoch 13/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7155 - loss: 0.8634 - val_accuracy: 0.3169 - val_loss: 4.2937
# Epoch 14/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7269 - loss: 0.8269 - val_accuracy: 0.6004 - val_loss: 1.3531
# Epoch 15/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7359 - loss: 0.8112 - val_accuracy: 0.6483 - val_loss: 1.1187
# Epoch 16/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7410 - loss: 0.7805 - val_accuracy: 0.4080 - val_loss: 2.4258
# Epoch 17/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7413 - loss: 0.7745 - val_accuracy: 0.5882 - val_loss: 1.4783
# Epoch 18/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7516 - loss: 0.7367 - val_accuracy: 0.4839 - val_loss: 1.7993
# Epoch 19/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7552 - loss: 0.7264 - val_accuracy: 0.5598 - val_loss: 1.7866
# Epoch 20/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7557 - loss: 0.7315 - val_accuracy: 0.4306 - val_loss: 1.9767
# Epoch 21/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7626 - loss: 0.7110 - val_accuracy: 0.5618 - val_loss: 2.1331
# Epoch 22/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7609 - loss: 0.7146 - val_accuracy: 0.5509 - val_loss: 1.8458
# Epoch 23/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7662 - loss: 0.6992 - val_accuracy: 0.5062 - val_loss: 2.0874
# Epoch 24/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7671 - loss: 0.7092 - val_accuracy: 0.6427 - val_loss: 1.0639
# Epoch 25/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7794 - loss: 0.6471 - val_accuracy: 0.5950 - val_loss: 1.5269
# Epoch 26/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7738 - loss: 0.6762 - val_accuracy: 0.4984 - val_loss: 1.7724
# Epoch 27/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7809 - loss: 0.6636 - val_accuracy: 0.4608 - val_loss: 2.7635
# Epoch 28/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7802 - loss: 0.6558 - val_accuracy: 0.7318 - val_loss: 0.8349
# Epoch 29/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7924 - loss: 0.6173 - val_accuracy: 0.6176 - val_loss: 1.2863
# Epoch 30/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7886 - loss: 0.6352 - val_accuracy: 0.5575 - val_loss: 1.7857
# Epoch 31/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7879 - loss: 0.6263 - val_accuracy: 0.5590 - val_loss: 1.6688
# Epoch 32/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7916 - loss: 0.6168 - val_accuracy: 0.6684 - val_loss: 1.2502
# Epoch 33/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7917 - loss: 0.6113 - val_accuracy: 0.5128 - val_loss: 2.0574
# Epoch 34/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7909 - loss: 0.6142 - val_accuracy: 0.6415 - val_loss: 1.3092
# Epoch 35/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7982 - loss: 0.5851 - val_accuracy: 0.5973 - val_loss: 1.3874
# Epoch 36/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8013 - loss: 0.5772 - val_accuracy: 0.6448 - val_loss: 1.2871
# Epoch 37/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8018 - loss: 0.5688 - val_accuracy: 0.5387 - val_loss: 1.9389
# Epoch 38/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8044 - loss: 0.5681 - val_accuracy: 0.5801 - val_loss: 1.8167
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7249 - loss: 0.8655
# Spectral + Vegetation Indices Test Accuracy: 0.7285
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#
# Training model with Spectral + DEM (104 channels)
# Subset shape: (26268, 5, 5, 104)
# Epoch 1/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.3364 - loss: 2.1920 - val_accuracy: 0.3149 - val_loss: 2.2431
# Epoch 2/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4579 - loss: 1.7586 - val_accuracy: 0.4194 - val_loss: 1.8142
# Epoch 3/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4991 - loss: 1.5965 - val_accuracy: 0.3682 - val_loss: 2.0775
# Epoch 4/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5310 - loss: 1.5018 - val_accuracy: 0.4806 - val_loss: 1.6778
# Epoch 5/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5570 - loss: 1.4253 - val_accuracy: 0.5788 - val_loss: 1.4141
# Epoch 6/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5744 - loss: 1.3819 - val_accuracy: 0.2964 - val_loss: 2.5547
# Epoch 7/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5986 - loss: 1.3147 - val_accuracy: 0.3618 - val_loss: 1.9909
# Epoch 8/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6098 - loss: 1.2653 - val_accuracy: 0.4466 - val_loss: 1.9196
# Epoch 9/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6061 - loss: 1.2636 - val_accuracy: 0.4722 - val_loss: 1.7177
# Epoch 10/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6142 - loss: 1.2315 - val_accuracy: 0.3986 - val_loss: 2.1608
# Epoch 11/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6304 - loss: 1.1804 - val_accuracy: 0.5080 - val_loss: 1.5965
# Epoch 12/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6349 - loss: 1.1582 - val_accuracy: 0.4572 - val_loss: 1.9985
# Epoch 13/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6429 - loss: 1.1149 - val_accuracy: 0.4314 - val_loss: 2.0738
# Epoch 14/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6484 - loss: 1.0968 - val_accuracy: 0.4468 - val_loss: 1.9866
# Epoch 15/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6819 - loss: 1.0108 - val_accuracy: 0.4052 - val_loss: 2.2109
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5743 - loss: 1.4428
# Spectral + DEM Test Accuracy: 0.5861
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#
# Training model with Spectral + Vegetation Indices + DEM (144 channels)
# Subset shape: (26268, 5, 5, 144)
# Epoch 1/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.3450 - loss: 2.1614 - val_accuracy: 0.3900 - val_loss: 2.0441
# Epoch 2/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4741 - loss: 1.7148 - val_accuracy: 0.3905 - val_loss: 2.3067
# Epoch 3/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5035 - loss: 1.5925 - val_accuracy: 0.1659 - val_loss: 3.7871
# Epoch 4/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5478 - loss: 1.4586 - val_accuracy: 0.4078 - val_loss: 1.9199
# Epoch 5/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5712 - loss: 1.4039 - val_accuracy: 0.5037 - val_loss: 1.5969
# Epoch 6/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5878 - loss: 1.3212 - val_accuracy: 0.3469 - val_loss: 2.6377
# Epoch 7/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6062 - loss: 1.2704 - val_accuracy: 0.5093 - val_loss: 1.5976
# Epoch 8/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6058 - loss: 1.2530 - val_accuracy: 0.4732 - val_loss: 2.0766
# Epoch 9/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6342 - loss: 1.1506 - val_accuracy: 0.4298 - val_loss: 1.9844
# Epoch 10/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6545 - loss: 1.1003 - val_accuracy: 0.4687 - val_loss: 1.6690
# Epoch 11/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6867 - loss: 1.0064 - val_accuracy: 0.6336 - val_loss: 1.2164
# Epoch 12/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7150 - loss: 0.9044 - val_accuracy: 0.4669 - val_loss: 1.8876
# Epoch 13/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7186 - loss: 0.8585 - val_accuracy: 0.6874 - val_loss: 0.9339
# Epoch 14/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7383 - loss: 0.8005 - val_accuracy: 0.6719 - val_loss: 1.0434
# Epoch 15/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7478 - loss: 0.7797 - val_accuracy: 0.6047 - val_loss: 1.2850
# Epoch 16/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7486 - loss: 0.7725 - val_accuracy: 0.5527 - val_loss: 1.5733
# Epoch 17/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7565 - loss: 0.7503 - val_accuracy: 0.5552 - val_loss: 1.8777
# Epoch 18/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7647 - loss: 0.7325 - val_accuracy: 0.6564 - val_loss: 1.0814
# Epoch 19/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7635 - loss: 0.7280 - val_accuracy: 0.7310 - val_loss: 0.8665
# Epoch 20/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7731 - loss: 0.6732 - val_accuracy: 0.5506 - val_loss: 1.4676
# Epoch 21/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7748 - loss: 0.6614 - val_accuracy: 0.5605 - val_loss: 1.5317
# Epoch 22/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7850 - loss: 0.6428 - val_accuracy: 0.5491 - val_loss: 2.0518
# Epoch 23/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7920 - loss: 0.6324 - val_accuracy: 0.3824 - val_loss: 3.1637
# Epoch 24/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7831 - loss: 0.6364 - val_accuracy: 0.6270 - val_loss: 1.4376
# Epoch 25/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7860 - loss: 0.6239 - val_accuracy: 0.5676 - val_loss: 1.6647
# Epoch 26/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7947 - loss: 0.6107 - val_accuracy: 0.7001 - val_loss: 0.9248
# Epoch 27/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7972 - loss: 0.5954 - val_accuracy: 0.4923 - val_loss: 2.1829
# Epoch 28/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7986 - loss: 0.5947 - val_accuracy: 0.6407 - val_loss: 1.3286
# Epoch 29/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7933 - loss: 0.5968 - val_accuracy: 0.6803 - val_loss: 1.2607
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7205 - loss: 0.8722
# Spectral + Vegetation Indices + DEM Test Accuracy: 0.7224
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#
# Summary of Results:
# Spectral Bands Only: Test Accuracy = 0.7176, Test Loss = 0.8580
# Spectral + Vegetation Indices: Test Accuracy = 0.7285, Test Loss = 0.8428
# Spectral + DEM: Test Accuracy = 0.5861, Test Loss = 1.4108
# Spectral + Vegetation Indices + DEM: Test Accuracy = 0.7224, Test Loss = 0.8527

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import json

# 11. Compute Additional Metrics
extended_results = {}
for combo_name, (indices, num_channels, description) in feature_combinations.items():
    print(f"\nComputing additional metrics for {description} ({num_channels} channels)")
    
    # Load the best model
    model = models.load_model(f'best_model_{combo_name}.keras')
    
    # Get test data for this combination
    X_subset = X[:, :, :, indices]
    X_train, X_test, y_train, y_test = train_test_split(X_subset, y_onehot, test_size=0.15, random_state=42, stratify=y_onehot)
    
    # Predict on test set
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_test_classes = np.argmax(y_test, axis=1)
    
    # Compute precision, recall, F1-score (macro-averaged)
    precision, recall, f1, _ = precision_recall_fscore_support(y_test_classes, y_pred_classes, average='macro')
    
    # Compute per-class accuracy from confusion matrix
    cm = confusion_matrix(y_test_classes, y_pred_classes)
    per_class_accuracy = cm.diagonal() / cm.sum(axis=1)
    per_class_accuracy_dict = {label_encoder.classes_[i]: acc for i, acc in enumerate(per_class_accuracy)}
    
    # Store extended results
    extended_results[combo_name] = {
        'description': description,
        'test_accuracy': results[combo_name]['test_accuracy'],
        'test_loss': results[combo_name]['test_loss'],
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'per_class_accuracy': per_class_accuracy_dict
    }
    
    # Print metrics
    print(f"{description}:")
    print(f"  Test Accuracy: {extended_results[combo_name]['test_accuracy']:.4f}")
    print(f"  Test Loss: {extended_results[combo_name]['test_loss']:.4f}")
    print(f"  Precision (macro): {precision:.4f}")
    print(f"  Recall (macro): {recall:.4f}")
    print(f"  F1-Score (macro): {f1:.4f}")
    print(f"  Per-Class Accuracy: {per_class_accuracy_dict}")

# 12. Summarize Metrics in a Table
metrics_df = pd.DataFrame({
    'Feature Combination': [extended_results[combo]['description'] for combo in extended_results],
    'Test Accuracy': [extended_results[combo]['test_accuracy'] for combo in extended_results],
    'Test Loss': [extended_results[combo]['test_loss'] for combo in extended_results],
    'Precision': [extended_results[combo]['precision'] for combo in extended_results],
    'Recall': [extended_results[combo]['recall'] for combo in extended_results],
    'F1-Score': [extended_results[combo]['f1_score'] for combo in extended_results]
})
print("\nMetrics Summary Table:")
print(metrics_df.to_string(index=False))

# Save metrics table to CSV
metrics_df.to_csv('metrics_summary.csv', index=False)

# 13. Plot Per-Class Accuracies
plt.figure(figsize=(12, 8))
for combo_name, result in extended_results.items():
    per_class_acc = result['per_class_accuracy']
    plt.plot(list(per_class_acc.keys()), list(per_class_acc.values()), marker='o', label=result['description'])
plt.xlabel('Class')
plt.ylabel('Per-Class Accuracy')
plt.title('Per-Class Accuracy by Feature Combination')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('per_class_accuracy.png')
plt.close()

# 14. Save Extended Results
with open('extended_results_summary.json', 'w') as f:
    json.dump({k: {kk: vv for kk, vv in v.items() if kk != 'history'} for k, v in extended_results.items()}, f, indent=4)
# Out:
# Computing additional metrics for Spectral Bands Only (96 channels)
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Spectral Bands Only:
#   Test Accuracy: 0.7176
#   Test Loss: 0.8580
#   Precision (macro): 0.6467
#   Recall (macro): 0.5666
#   F1-Score (macro): 0.5748
#   Per-Class Accuracy: {'alder': 0.8340425531914893, 'birch': 0.5286885245901639, 'black pine': 0.2553191489361702, 'cherry': 0.043478260869565216, 'douglas fir': 0.8152610441767069, 'english oak': 0.707395498392283, 'european ash': 0.5045045045045045, 'european beech': 0.8125, 'european larch': 0.38461538461538464, 'japanese larch': 0.7151515151515152, 'linden': 0.0, 'norway spruce': 0.759656652360515, 'poplar': 0.13636363636363635, 'red oak': 0.7604790419161677, 'scots pine': 0.9420970266040689, 'sessile oak': 0.8663366336633663, 'silver fir': 0.7466666666666667, 'sycamore maple': 0.3316831683168317, 'weymouth pine': 0.6212121212121212}
#
# Computing additional metrics for Spectral + Vegetation Indices (136 channels)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Spectral + Vegetation Indices:
#   Test Accuracy: 0.7285
#   Test Loss: 0.8428
#   Precision (macro): 0.7088
#   Recall (macro): 0.6140
#   F1-Score (macro): 0.6136
#   Per-Class Accuracy: {'alder': 0.6340425531914894, 'birch': 0.45081967213114754, 'black pine': 0.40425531914893614, 'cherry': 0.17391304347826086, 'douglas fir': 0.4578313253012048, 'english oak': 0.887459807073955, 'european ash': 0.5900900900900901, 'european beech': 0.9419642857142857, 'european larch': 0.7350427350427351, 'japanese larch': 0.7212121212121212, 'linden': 0.10526315789473684, 'norway spruce': 0.8283261802575107, 'poplar': 0.29545454545454547, 'red oak': 0.49700598802395207, 'scots pine': 0.8951486697965572, 'sessile oak': 0.8366336633663366, 'silver fir': 0.8266666666666667, 'sycamore maple': 0.4603960396039604, 'weymouth pine': 0.9242424242424242}
#
# Computing additional metrics for Spectral + DEM (104 channels)
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Spectral + DEM:
#   Test Accuracy: 0.5861
#   Test Loss: 1.4108
#   Precision (macro): 0.4876
#   Recall (macro): 0.3805
#   F1-Score (macro): 0.3840
#   Per-Class Accuracy: {'alder': 0.4553191489361702, 'birch': 0.12704918032786885, 'black pine': 0.0, 'cherry': 0.0, 'douglas fir': 0.4738955823293173, 'english oak': 0.6945337620578779, 'european ash': 0.36036036036036034, 'european beech': 0.8816964285714286, 'european larch': 0.3162393162393162, 'japanese larch': 0.7272727272727273, 'linden': 0.0, 'norway spruce': 0.8583690987124464, 'poplar': 0.0, 'red oak': 0.5389221556886228, 'scots pine': 0.9295774647887324, 'sessile oak': 0.3910891089108911, 'silver fir': 0.32, 'sycamore maple': 0.06435643564356436, 'weymouth pine': 0.09090909090909091}
#
# Computing additional metrics for Spectral + Vegetation Indices + DEM (144 channels)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Spectral + Vegetation Indices + DEM:
#   Test Accuracy: 0.7224
#   Test Loss: 0.8527
#   Precision (macro): 0.6562
#   Recall (macro): 0.6060
#   F1-Score (macro): 0.6010
#   Per-Class Accuracy: {'alder': 0.4808510638297872, 'birch': 0.4385245901639344, 'black pine': 0.5531914893617021, 'cherry': 0.043478260869565216, 'douglas fir': 0.570281124497992, 'english oak': 0.8006430868167203, 'european ash': 0.581081081081081, 'european beech': 0.9308035714285714, 'european larch': 0.6068376068376068, 'japanese larch': 0.8484848484848485, 'linden': 0.0, 'norway spruce': 0.8733905579399142, 'poplar': 0.29545454545454547, 'red oak': 0.6586826347305389, 'scots pine': 0.8622848200312989, 'sessile oak': 0.6336633663366337, 'silver fir': 0.96, 'sycamore maple': 0.5891089108910891, 'weymouth pine': 0.7878787878787878}
#
# Metrics Summary Table:
#                 Feature Combination  Test Accuracy  Test Loss  Precision   Recall  F1-Score
#                 Spectral Bands Only       0.717584   0.857975   0.646729 0.566603  0.574788
#       Spectral + Vegetation Indices       0.728495   0.842837   0.708819 0.613988  0.613636
#                      Spectral + DEM       0.586146   1.410754   0.487562 0.380505  0.384032
# Spectral + Vegetation Indices + DEM       0.722405   0.852657   0.656211 0.606034  0.601004
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import layers, models
import joblib
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import json

# 2. Handle NaN Values
print("\nChecking for NaN values...")
nan_mask = np.any(np.isnan(X), axis=(1, 2, 3))
nan_count = np.sum(nan_mask)
print(f"Found {nan_count} samples with NaN values")
if nan_count > 0:
    print(f"Removing {nan_count} samples with NaN values")
    valid_mask = ~nan_mask
    X = X[valid_mask]
    y = y[valid_mask]
    print(f"New data shape after removing NaN: {X.shape}")

# 3. Normalize Data
print("\nNormalizing data...")
X_min = np.nanmin(X, axis=(0, 1, 2), keepdims=True)
X_max = np.nanmax(X, axis=(0, 1, 2), keepdims=True)
X = (X - X_min) / (X_max - X_min + 1e-6)  # Min-max normalization to [0, 1]
print(f"Data range after normalization: min={np.nanmin(X):.4f}, max={np.nanmax(X):.4f}")

# 4. Preprocess Labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
y_onehot = tf.keras.utils.to_categorical(y_encoded)
num_classes = len(label_encoder.classes_)
print(f"\nData shape: {X.shape}, Number of classes: {num_classes}")

# 5. Define Feature Combination (Spectral + Selected Indices + DEM)
bands = ['ARVI', 'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'DEM', 'EVI', 'EVI2', 'NDVI', 'NDWI']
months = ['', '_1', '_2', '_3', '_4', '_5', '_6', '_7']
band_columns = [band + month for month in months for band in bands]  # 18 bands × 8 months = 144 channels

spectral_bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12']  # 12 bands
veg_indices = ['NDVI', 'EVI', 'SAVI', 'NDWI']  # 4 important indices
dem_band = ['DEM']  # 1 band

# Create and verify channel indices
spectral_indices = [i for i, col in enumerate(band_columns) if any(col.startswith(band) for band in spectral_bands)]  # 12 × 8 = 96 channels
veg_indices_indices = [i for i, col in enumerate(band_columns) if any(col.startswith(band) for band in veg_indices)]  # 4 × 8 = 32 channels
dem_indices = [i for i, col in enumerate(band_columns) if col.startswith('DEM')]  # 1 × 8 = 8 channels

# Combine for single feature set
feature_indices = spectral_indices + veg_indices_indices + dem_indices
num_channels = 96 + 32 + 8  # 136 channels
description = 'Spectral + Selected Indices + DEM'

# Debug channel indices
print("\nDebugging channel indices:")
print(f"Spectral indices ({len(spectral_indices)}): {[band_columns[i] for i in spectral_indices]}")
print(f"Vegetation indices ({len(veg_indices_indices)}): {[band_columns[i] for i in veg_indices_indices]}")
print(f"DEM indices ({len(dem_indices)}): {[band_columns[i] for i in dem_indices]}")
print(f"Combined indices ({len(feature_indices)}): {[band_columns[i] for i in feature_indices]}")

# Verify expected channel counts
expected_veg_channels = 4 * len(months)  # 4 bands × 8 months
if len(veg_indices_indices) != expected_veg_channels:
    print(f"Warning: Expected {expected_veg_channels} vegetation indices channels, got {len(veg_indices_indices)}")
    missing_veg_bands = [band for band in veg_indices if not any(col.startswith(band) for col in band_columns)]
    print(f"Missing vegetation indices: {missing_veg_bands}")

# 6. Define CNN Model
def build_cnn(input_shape, num_classes):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

# 7. Data Augmentation
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
])

# 8. Train and Evaluate Model
print(f"\nTraining model with {description} ({num_channels} channels)")

# Select feature subset
X_subset = X[:, :, :, feature_indices]
print(f"Subset shape: {X_subset.shape}")

# Verify no NaN in subset
if np.any(np.isnan(X_subset)):
    print(f"Warning: NaN values found in {description} subset")

# Train-test-validation split
X_train, X_test, y_train, y_test = train_test_split(X_subset, y_onehot, test_size=0.15, random_state=42, stratify=y_onehot)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1765, random_state=42, stratify=y_train)

# Build and compile model
model = build_cnn(input_shape=(5, 5, num_channels), num_classes=num_classes)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train model
history = model.fit(
    data_augmentation(X_train), y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=32,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
        tf.keras.callbacks.ModelCheckpoint('best_model.keras', save_best_only=True)
    ],
    verbose=1
)

# Evaluate model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"{description} Test Accuracy: {test_accuracy:.4f}")

# Compute additional metrics
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

# Precision, recall, F1-score (macro-averaged)
precision, recall, f1, _ = precision_recall_fscore_support(y_test_classes, y_pred_classes, average='macro')

# Per-class accuracy from confusion matrix
cm = confusion_matrix(y_test_classes, y_pred_classes)
per_class_accuracy = cm.diagonal() / cm.sum(axis=1)
per_class_accuracy_dict = {label_encoder.classes_[i]: acc for i, acc in enumerate(per_class_accuracy)}

# Plot confusion matrix
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Confusion Matrix: {description}')
plt.savefig('confusion_matrix.png')
plt.close()

# 9. Summarize Metrics
metrics_dict = {
    'description': description,
    'test_accuracy': test_accuracy,
    'test_loss': test_loss,
    'precision': precision,
    'recall': recall,
    'f1_score': f1,
    'per_class_accuracy': per_class_accuracy_dict
}
print(f"\nMetrics Summary:")
print(f"Description: {description}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")
print(f"Precision (macro): {precision:.4f}")
print(f"Recall (macro): {recall:.4f}")
print(f"F1-Score (macro): {f1:.4f}")
print(f"Per-Class Accuracy: {per_class_accuracy_dict}")

# Save metrics to CSV
metrics_df = pd.DataFrame([metrics_dict], columns=['description', 'test_accuracy', 'test_loss', 'precision', 'recall', 'f1_score'])
metrics_df.to_csv('metrics_summary.csv', index=False)

# 10. Plot Per-Class Accuracies
plt.figure(figsize=(12, 8))
plt.plot(list(per_class_accuracy_dict.keys()), list(per_class_accuracy_dict.values()), marker='o', label=description)
plt.xlabel('Class')
plt.ylabel('Per-Class Accuracy')
plt.title('Per-Class Accuracy')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('per_class_accuracy.png')
plt.close()

# Save results
with open('results_summary.json', 'w') as f:
    json.dump({k: v for k, v in metrics_dict.items() if k != 'history'}, f, indent=4)

# Save label encoder
joblib.dump(label_encoder, 'label_encoder.pkl')
# Out:
# Checking for NaN values...
# Found 0 samples with NaN values
#
# Normalizing data...
# Data range after normalization: min=0.0000, max=1.0000
#
# Data shape: (26268, 5, 5, 144), Number of classes: 19
#
# Debugging channel indices:
# Spectral indices (96): ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'B1_1', 'B2_1', 'B3_1', 'B4_1', 'B5_1', 'B6_1', 'B7_1', 'B8_1', 'B8A_1', 'B9_1', 'B11_1', 'B12_1', 'B1_2', 'B2_2', 'B3_2', 'B4_2', 'B5_2', 'B6_2', 'B7_2', 'B8_2', 'B8A_2', 'B9_2', 'B11_2', 'B12_2', 'B1_3', 'B2_3', 'B3_3', 'B4_3', 'B5_3', 'B6_3', 'B7_3', 'B8_3', 'B8A_3', 'B9_3', 'B11_3', 'B12_3', 'B1_4', 'B2_4', 'B3_4', 'B4_4', 'B5_4', 'B6_4', 'B7_4', 'B8_4', 'B8A_4', 'B9_4', 'B11_4', 'B12_4', 'B1_5', 'B2_5', 'B3_5', 'B4_5', 'B5_5', 'B6_5', 'B7_5', 'B8_5', 'B8A_5', 'B9_5', 'B11_5', 'B12_5', 'B1_6', 'B2_6', 'B3_6', 'B4_6', 'B5_6', 'B6_6', 'B7_6', 'B8_6', 'B8A_6', 'B9_6', 'B11_6', 'B12_6', 'B1_7', 'B2_7', 'B3_7', 'B4_7', 'B5_7', 'B6_7', 'B7_7', 'B8_7', 'B8A_7', 'B9_7', 'B11_7', 'B12_7']
# Vegetation indices (32): ['EVI', 'EVI2', 'NDVI', 'NDWI', 'EVI_1', 'EVI2_1', 'NDVI_1', 'NDWI_1', 'EVI_2', 'EVI2_2', 'NDVI_2', 'NDWI_2', 'EVI_3', 'EVI2_3', 'NDVI_3', 'NDWI_3', 'EVI_4', 'EVI2_4', 'NDVI_4', 'NDWI_4', 'EVI_5', 'EVI2_5', 'NDVI_5', 'NDWI_5', 'EVI_6', 'EVI2_6', 'NDVI_6', 'NDWI_6', 'EVI_7', 'EVI2_7', 'NDVI_7', 'NDWI_7']
# DEM indices (8): ['DEM', 'DEM_1', 'DEM_2', 'DEM_3', 'DEM_4', 'DEM_5', 'DEM_6', 'DEM_7']
# Combined indices (136): ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'B1_1', 'B2_1', 'B3_1', 'B4_1', 'B5_1', 'B6_1', 'B7_1', 'B8_1', 'B8A_1', 'B9_1', 'B11_1', 'B12_1', 'B1_2', 'B2_2', 'B3_2', 'B4_2', 'B5_2', 'B6_2', 'B7_2', 'B8_2', 'B8A_2', 'B9_2', 'B11_2', 'B12_2', 'B1_3', 'B2_3', 'B3_3', 'B4_3', 'B5_3', 'B6_3', 'B7_3', 'B8_3', 'B8A_3', 'B9_3', 'B11_3', 'B12_3', 'B1_4', 'B2_4', 'B3_4', 'B4_4', 'B5_4', 'B6_4', 'B7_4', 'B8_4', 'B8A_4', 'B9_4', 'B11_4', 'B12_4', 'B1_5', 'B2_5', 'B3_5', 'B4_5', 'B5_5', 'B6_5', 'B7_5', 'B8_5', 'B8A_5', 'B9_5', 'B11_5', 'B12_5', 'B1_6', 'B2_6', 'B3_6', 'B4_6', 'B5_6', 'B6_6', 'B7_6', 'B8_6', 'B8A_6', 'B9_6', 'B11_6', 'B12_6', 'B1_7', 'B2_7', 'B3_7', 'B4_7', 'B5_7', 'B6_7', 'B7_7', 'B8_7', 'B8A_7', 'B9_7', 'B11_7', 'B12_7', 'EVI', 'EVI2', 'NDVI', 'NDWI', 'EVI_1', 'EVI2_1', 'NDVI_1', 'NDWI_1', 'EVI_2', 'EVI2_2', 'NDVI_2', 'NDWI_2', 'EVI_3', 'EVI2_3', 'NDVI_3', 'NDWI_3', 'EVI_4', 'EVI2_4', 'NDVI_4', 'NDWI_4', 'EVI_5', 'EVI2_5', 'NDVI_5', 'NDWI_5', 'EVI_6', 'EVI2_6', 'NDVI_6', 'NDWI_6', 'EVI_7', 'EVI2_7', 'NDVI_7', 'NDWI_7', 'DEM', 'DEM_1', 'DEM_2', 'DEM_3', 'DEM_4', 'DEM_5', 'DEM_6', 'DEM_7']
#
# Training model with Spectral + Selected Indices + DEM (136 channels)
# Subset shape: (26268, 5, 5, 136)
# Epoch 1/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.3339 - loss: 2.2076 - val_accuracy: 0.3570 - val_loss: 2.2275
# Epoch 2/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4775 - loss: 1.6992 - val_accuracy: 0.4024 - val_loss: 1.7606
# Epoch 3/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5042 - loss: 1.6061 - val_accuracy: 0.2657 - val_loss: 3.0992
# Epoch 4/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5259 - loss: 1.5181 - val_accuracy: 0.2271 - val_loss: 5.0659
# Epoch 5/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5596 - loss: 1.4268 - val_accuracy: 0.4133 - val_loss: 2.1369
# Epoch 6/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5674 - loss: 1.3704 - val_accuracy: 0.5742 - val_loss: 1.3664
# Epoch 7/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5798 - loss: 1.3478 - val_accuracy: 0.4248 - val_loss: 2.0782
# Epoch 8/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6077 - loss: 1.2849 - val_accuracy: 0.4940 - val_loss: 1.6456
# Epoch 9/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6070 - loss: 1.2567 - val_accuracy: 0.4781 - val_loss: 1.9324
# Epoch 10/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6227 - loss: 1.2166 - val_accuracy: 0.4945 - val_loss: 1.9228
# Epoch 11/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6355 - loss: 1.1712 - val_accuracy: 0.5991 - val_loss: 1.2864
# Epoch 12/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6425 - loss: 1.1349 - val_accuracy: 0.5049 - val_loss: 1.7393
# Epoch 13/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6791 - loss: 1.0088 - val_accuracy: 0.2426 - val_loss: 3.1815
# Epoch 14/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7031 - loss: 0.9401 - val_accuracy: 0.5341 - val_loss: 1.4385
# Epoch 15/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7254 - loss: 0.8568 - val_accuracy: 0.5326 - val_loss: 1.5247
# Epoch 16/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7367 - loss: 0.8133 - val_accuracy: 0.6432 - val_loss: 1.0835
# Epoch 17/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7405 - loss: 0.7893 - val_accuracy: 0.5823 - val_loss: 1.3150
# Epoch 18/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7433 - loss: 0.7810 - val_accuracy: 0.6595 - val_loss: 1.2129
# Epoch 19/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7568 - loss: 0.7373 - val_accuracy: 0.5661 - val_loss: 1.5431
# Epoch 20/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7552 - loss: 0.7396 - val_accuracy: 0.6501 - val_loss: 1.0767
# Epoch 21/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7619 - loss: 0.7123 - val_accuracy: 0.6351 - val_loss: 1.2009
# Epoch 22/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7660 - loss: 0.7009 - val_accuracy: 0.6882 - val_loss: 1.1125
# Epoch 23/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7641 - loss: 0.7038 - val_accuracy: 0.5856 - val_loss: 1.6104
# Epoch 24/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7668 - loss: 0.6930 - val_accuracy: 0.6092 - val_loss: 1.4690
# Epoch 25/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7768 - loss: 0.6689 - val_accuracy: 0.6075 - val_loss: 1.6173
# Epoch 26/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7757 - loss: 0.6609 - val_accuracy: 0.5978 - val_loss: 1.4270
# Epoch 27/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7826 - loss: 0.6544 - val_accuracy: 0.5806 - val_loss: 1.3945
# Epoch 28/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7876 - loss: 0.6404 - val_accuracy: 0.5887 - val_loss: 1.5357
# Epoch 29/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7871 - loss: 0.6335 - val_accuracy: 0.6882 - val_loss: 1.0448
# Epoch 30/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7912 - loss: 0.6187 - val_accuracy: 0.6184 - val_loss: 1.5079
# Epoch 31/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7924 - loss: 0.6216 - val_accuracy: 0.5960 - val_loss: 1.4388
# Epoch 32/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7991 - loss: 0.5952 - val_accuracy: 0.7145 - val_loss: 1.0183
# Epoch 33/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7978 - loss: 0.5921 - val_accuracy: 0.6539 - val_loss: 1.2887
# Epoch 34/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7976 - loss: 0.5912 - val_accuracy: 0.6734 - val_loss: 1.0706
# Epoch 35/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7959 - loss: 0.5922 - val_accuracy: 0.6920 - val_loss: 1.0856
# Epoch 36/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8060 - loss: 0.5666 - val_accuracy: 0.6869 - val_loss: 1.0351
# Epoch 37/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8024 - loss: 0.5677 - val_accuracy: 0.6930 - val_loss: 1.0344
# Epoch 38/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8074 - loss: 0.5599 - val_accuracy: 0.6724 - val_loss: 1.3279
# Epoch 39/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8077 - loss: 0.5448 - val_accuracy: 0.6176 - val_loss: 1.2219
# Epoch 40/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8099 - loss: 0.5470 - val_accuracy: 0.7270 - val_loss: 0.8998
# Epoch 41/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8093 - loss: 0.5523 - val_accuracy: 0.7407 - val_loss: 0.8669
# Epoch 42/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8097 - loss: 0.5450 - val_accuracy: 0.6991 - val_loss: 0.9979
# Epoch 43/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8203 - loss: 0.5166 - val_accuracy: 0.7090 - val_loss: 1.0379
# Epoch 44/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8188 - loss: 0.5217 - val_accuracy: 0.5428 - val_loss: 3.3029
# Epoch 45/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8161 - loss: 0.5158 - val_accuracy: 0.7498 - val_loss: 0.8662
# Epoch 46/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8270 - loss: 0.4937 - val_accuracy: 0.6717 - val_loss: 1.2454
# Epoch 47/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8286 - loss: 0.4973 - val_accuracy: 0.6630 - val_loss: 1.2547
# Epoch 48/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8259 - loss: 0.4926 - val_accuracy: 0.6476 - val_loss: 1.3086
# Epoch 49/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8310 - loss: 0.4888 - val_accuracy: 0.6389 - val_loss: 1.3330
# Epoch 50/50
# 575/575 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8311 - loss: 0.4784 - val_accuracy: 0.7488 - val_loss: 0.8928
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7450 - loss: 0.9341
# Spectral + Selected Indices + DEM Test Accuracy: 0.7463
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Metrics Summary:
# Description: Spectral + Selected Indices + DEM
# Test Accuracy: 0.7463
# Test Loss: 0.9204
# Precision (macro): 0.6970
# Recall (macro): 0.6200
# F1-Score (macro): 0.6235
# Per-Class Accuracy: {'alder': 0.8127659574468085, 'birch': 0.6352459016393442, 'black pine': 0.19148936170212766, 'cherry': 0.0, 'douglas fir': 0.8514056224899599, 'english oak': 0.8585209003215434, 'european ash': 0.3153153153153153, 'european beech': 0.7767857142857143, 'european larch': 0.5641025641025641, 'japanese larch': 0.7696969696969697, 'linden': 0.2631578947368421, 'norway spruce': 0.8605150214592274, 'poplar': 0.5454545454545454, 'red oak': 0.7544910179640718, 'scots pine': 0.8544600938967136, 'sessile oak': 0.9158415841584159, 'silver fir': 0.8933333333333333, 'sycamore maple': 0.599009900990099, 'weymouth pine': 0.3181818181818182}
# ['label_encoder.pkl']

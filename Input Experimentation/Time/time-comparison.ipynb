# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import layers, models
import geopandas as gpd
import ast
import os
import json
import joblib
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Define Data Paths and Parameters
time_periods = ['july-2022', 'august-2022', 'mar-oct-2022', 'all-2022']
patch_size = 5  # Fixed to 5x5 based on GEE code
data_folders = [
    '/kaggle/input/july2022',  # Update with actual path
    '/kaggle/input/august',  # Update with actual path
    '/kaggle/input/mar-oct',  # Update with actual path
    '/kaggle/input/all2022'  # Update with actual path
]

# Define bands
base_bands = [
    'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12',
    'NDVI', 'EVI', 'SAVI', 'NDWI', 'DEM'
]
time_period_configs = {
    'july-2022': {'months': [''], 'num_bands': 17},
    'august-2022': {'months': [''], 'num_bands': 17},
    'mar-oct-2022': {'months': ['', '_1', '_2', '_3', '_4', '_5', '_6', '_7'], 'num_bands': 136},
    'all-2022': {'months': ['', '_1', '_2', '_3', '_4', '_5', '_6', '_7', '_8', '_9', '_10', '_11'], 'num_bands': 204}
}

# 2. Function to Load Data for a Given Time Period
def load_data_for_time_period(time_period, folder_path):
    all_features = []
    all_labels = []
    invalid_samples = []
    # Get band columns for the time period
    band_columns = [band + month for month in time_period_configs[time_period]['months'] for band in base_bands]
    # Verify available columns
    available_columns = None
    for file in os.listdir(folder_path):
        if file.endswith(".geojson"):
            gdf = gpd.read_file(os.path.join(folder_path, file))
            available_columns = [col for col in band_columns if col in gdf.columns]
            # Debugging: Print sample data for first few rows
            print(f"\nInspecting first 2 rows of {file}:")
            for idx in range(min(2, len(gdf))):
                print(f"Row {idx}:")
                for col in available_columns[:5]:  # Print first 5 bands for brevity
                    print(f"  {col}: {gdf[col].iloc[idx]}")
                print(f"  l3_species: {gdf['l3_species'].iloc[idx]}")
            break
    if not available_columns:
        raise ValueError(f"No valid GeoJSON files found in {folder_path}")
    print(f"Time period {time_period}: Available columns: {len(available_columns)}/{len(band_columns)}")
    expected_shape = (patch_size, patch_size, len(available_columns))

    # Load all GeoJSON files
    for file in os.listdir(folder_path):
        if file.endswith(".geojson"):
            gdf = gpd.read_file(os.path.join(folder_path, file))
            for idx, row in gdf.iterrows():
                try:
                    if row['l3_species'] is None or not isinstance(row['l3_species'], str):
                        raise ValueError(f"Invalid label at row {idx}: {row['l3_species']}")
                    patches = []
                    for col in available_columns:
                        val = row[col]
                        if val is None:
                            raise ValueError(f"Null value for band {col}")
                        if isinstance(val, (list, np.ndarray)):
                            arr = np.array(val, dtype=np.float32).reshape(patch_size, patch_size)
                        elif isinstance(val, str):
                            try:
                                arr = np.array(json.loads(val), dtype=np.float32).reshape(patch_size, patch_size)
                            except json.JSONDecodeError:
                                arr = np.array(ast.literal_eval(val), dtype=np.float32).reshape(patch_size, patch_size)
                        elif isinstance(val, (float, np.float32, np.float64)):
                            arr = np.full((patch_size, patch_size), val, dtype=np.float32)
                        else:
                            raise ValueError(f"Unexpected data type for band {col}: {type(val)}")
                        patches.append(arr)

                    patch = np.stack(patches, axis=-1)
                    if patch.shape != expected_shape:
                        raise ValueError(f"Unexpected patch shape: {patch.shape}, expected {expected_shape}")
                    all_features.append(patch)
                    all_labels.append(row['l3_species'])
                except Exception as e:
                    invalid_samples.append((file, idx, str(e)))
                    continue

    if invalid_samples:
        print(f"\nTime period {time_period}: Skipped {len(invalid_samples)} invalid samples")
        for file, idx, error in invalid_samples[:5]:
            print(f"File: {file}, Row: {idx}, Error: {error}")
        with open(f'invalid_samples_{time_period}.json', 'w') as f:
            json.dump(invalid_samples, f, indent=4)

    if not all_features:
        raise ValueError(f"No valid samples loaded for time period {time_period}. Check GeoJSON files.")
    X = np.array(all_features, dtype=np.float32)
    y = np.array(all_labels)
    print(f"Time period {time_period}: Loaded {len(all_features)} valid samples with shape {X.shape}")
    print(f"Time period {time_period}: Unique labels: {np.unique(y).tolist()}")
    return X, y, invalid_samples, available_columns

# 3. Define CNN Model
def build_cnn(input_shape, num_classes):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

# 4. Data Augmentation
def get_data_augmentation():
    return tf.keras.Sequential([
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(0.2),
    ])

# 5. Train and Evaluate for Each Time Period
results = {}
label_encoders = {}  # Store separate LabelEncoder for each time period

for time_period, folder_path in zip(time_periods, data_folders):
    print(f"\nProcessing time period: {time_period}")
    if not os.path.exists(folder_path):
        print(f"Folder {folder_path} does not exist.")
        continue

    # Load data
    try:
        X, y, invalid_samples, available_columns = load_data_for_time_period(time_period, folder_path)
    except Exception as e:
        print(f"Error loading data for time period {time_period}: {e}")
        continue

    # Handle NaN values
    print(f"\nTime period {time_period}: Checking for NaN values...")
    nan_mask = np.any(np.isnan(X), axis=(1, 2, 3))
    nan_count = np.sum(nan_mask)
    if nan_count > 0:
        print(f"Time period {time_period}: Removing {nan_count} samples with NaN values")
        valid_mask = ~nan_mask
        X = X[valid_mask]
        y = y[valid_mask]
        print(f"Time period {time_period}: New data shape after removing NaN: {X.shape}")

    # Normalize data
    print(f"Time period {time_period}: Normalizing data...")
    X_min = np.nanmin(X, axis=(0, 1, 2), keepdims=True)
    X_max = np.nanmax(X, axis=(0, 1, 2), keepdims=True)
    X = (X - X_min) / (X_max - X_min + 1e-6)
    print(f"Time period {time_period}: Data range after normalization: min={np.nanmin(X):.4f}, max={np.nanmax(X):.4f}")

    # Encode labels
    try:
        label_encoder = LabelEncoder()
        y_encoded = label_encoder.fit_transform(y)
        y_onehot = tf.keras.utils.to_categorical(y_encoded)
        num_classes = len(label_encoder.classes_)
        label_encoders[time_period] = label_encoder  # Store encoder
        print(f"Time period {time_period}: Data shape: {X.shape}, Number of classes: {num_classes}")
        print(f"Time period {time_period}: Class names: {label_encoder.classes_.tolist()}")
    except Exception as e:
        print(f"Error encoding labels for time period {time_period}: {e}")
        continue

    # Train-test-validation split
    try:
        X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.15, random_state=42, stratify=y_onehot)
        X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1765, random_state=42, stratify=y_train)
        print(f"Time period {time_period}: Train shape: {X_train.shape}, Validation shape: {X_val.shape}, Test shape: {X_test.shape}")
    except Exception as e:
        print(f"Error splitting data for time period {time_period}: {e}")
        continue

    # Build and compile model
    try:
        model = build_cnn(input_shape=(patch_size, patch_size, len(available_columns)), num_classes=num_classes)
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    except Exception as e:
        print(f"Error building model for time period {time_period}: {e}")
        continue

    # Train model
    try:
        history = model.fit(
            get_data_augmentation()(X_train), y_train,
            validation_data=(X_val, y_val),
            epochs=50,
            batch_size=16,
            callbacks=[
                tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
                tf.keras.callbacks.ModelCheckpoint(f'best_model_{time_period}.keras', save_best_only=True)
            ],
            verbose=1
        )
    except Exception as e:
        print(f"Error training model for time period {time_period}: {e}")
        continue

    # Evaluate model
    try:
        test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
        print(f"Time period {time_period}: Test Accuracy: {test_accuracy:.4f}, Test Loss: {test_loss:.4f}")

        # Compute additional metrics
        y_pred = model.predict(X_test, verbose=0)
        y_pred_classes = np.argmax(y_pred, axis=1)
        y_test_classes = np.argmax(y_test, axis=1)

        # Classification report
        class_report = classification_report(y_test_classes, y_pred_classes, target_names=label_encoder.classes_, output_dict=True)
        print(f"\nTime period {time_period}: Classification Report:")
        print(classification_report(y_test_classes, y_pred_classes, target_names=label_encoder.classes_))

        # Confusion matrix
        cm = confusion_matrix(y_test_classes, y_pred_classes)
        plt.figure(figsize=(12, 10))
        sns.heatmap(cm, annot=True, fmt='d', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.title(f'Confusion Matrix: Time Period {time_period}')
        plt.savefig(f'confusion_matrix_{time_period}.png')
        plt.close()

        # Store results
        results[time_period] = {
            'time_period': time_period,
            'test_accuracy': test_accuracy,
            'test_loss': test_loss,
            'classification_report': class_report,
            'history': history.history,
            'num_classes': num_classes,
            'class_names': label_encoder.classes_.tolist()
        }
    except Exception as e:
        print(f"Error evaluating model for time period {time_period}: {e}")
        continue

# 6. Compare Results
print("\nSummary of Results:")
for key, result in results.items():
    print(f"\nTime Period {result['time_period']}:")
    print(f"  Test Accuracy: {result['test_accuracy']:.4f}")
    print(f"  Test Loss: {result['test_loss']:.4f}")
    print(f"  Weighted Precision: {result['classification_report']['weighted avg']['precision']:.4f}")
    print(f"  Weighted Recall: {result['classification_report']['weighted avg']['recall']:.4f}")
    print(f"  Weighted F1-Score: {result['classification_report']['weighted avg']['f1-score']:.4f}")
    print(f"  Macro Precision: {result['classification_report']['macro avg']['precision']:.4f}")
    print(f"  Macro Recall: {result['classification_report']['macro avg']['recall']:.4f}")
    print(f"  Macro F1-Score: {result['classification_report']['macro avg']['f1-score']:.4f}")
    print(f"  Number of Classes: {result['num_classes']}")
    print(f"  Class Names: {result['class_names']}")

# Plot accuracy comparison
if results:
    plt.figure(figsize=(10, 6))
    completed_periods = [key for key in results]
    accuracies = [results[key]['test_accuracy'] for key in results]
    plt.bar(completed_periods, accuracies)
    plt.xlabel('Time Period')
    plt.ylabel('Test Accuracy')
    plt.title('Test Accuracy by Time Period')
    plt.tight_layout()
    plt.savefig('accuracy_comparison_time_periods.png')
    plt.close()

    # Plot weighted F1-score comparison
    plt.figure(figsize=(10, 6))
    f1_scores = [results[key]['classification_report']['weighted avg']['f1-score'] for key in results]
    plt.bar(completed_periods, f1_scores)
    plt.xlabel('Time Period')
    plt.ylabel('Weighted F1-Score')
    plt.title('Weighted F1-Score by Time Period')
    plt.tight_layout()
    plt.savefig('f1_score_comparison_time_periods.png')
    plt.close()

# 7. Save Label Encoders and Results
for time_period, encoder in label_encoders.items():
    joblib.dump(encoder, f'label_encoder_{time_period}.pkl')
with open('results_summary_time_periods.json', 'w') as f:
    json.dump({k: {kk: vv for kk, vv in v.items() if kk != 'history'} for k, v in results.items()}, f, indent=4)
# Out:
# 2025-06-29 00:32:55.528389: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751157175.722394      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751157175.774939      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Processing time period: july-2022
#
# Inspecting first 2 rows of needleleaf_pine_weymouth pinejuly-2022.geojson:
# Row 0:
#   B1: None
#   B2: None
#   B3: None
#   B4: None
#   B5: None
#   l3_species: weymouth pine
# Row 1:
#   B1: None
#   B2: None
#   B3: None
#   B4: None
#   B5: None
#   l3_species: weymouth pine
# Time period july-2022: Available columns: 17/17
#
# Time period july-2022: Skipped 25577 invalid samples
# File: needleleaf_pine_weymouth pinejuly-2022.geojson, Row: 0, Error: Null value for band B1
# File: needleleaf_pine_weymouth pinejuly-2022.geojson, Row: 1, Error: Null value for band B1
# File: needleleaf_pine_weymouth pinejuly-2022.geojson, Row: 2, Error: Null value for band B1
# File: needleleaf_pine_weymouth pinejuly-2022.geojson, Row: 3, Error: Null value for band B1
# File: needleleaf_pine_weymouth pinejuly-2022.geojson, Row: 4, Error: Null value for band B1
# Time period july-2022: Loaded 12330 valid samples with shape (12330, 5, 5, 17)
# Time period july-2022: Unique labels: ['alder', 'birch', 'black pine', 'cherry', 'douglas fir', 'english oak', 'european ash', 'european beech', 'european larch', 'japanese larch', 'linden', 'norway spruce', 'poplar', 'red oak', 'scots pine', 'sessile oak', 'silver fir', 'sycamore maple', 'weymouth pine']
#
# Time period july-2022: Checking for NaN values...
# Time period july-2022: Normalizing data...
# Time period july-2022: Data range after normalization: min=0.0000, max=1.0000
# Time period july-2022: Data shape: (12330, 5, 5, 17), Number of classes: 19
# Time period july-2022: Class names: ['alder', 'birch', 'black pine', 'cherry', 'douglas fir', 'english oak', 'european ash', 'european beech', 'european larch', 'japanese larch', 'linden', 'norway spruce', 'poplar', 'red oak', 'scots pine', 'sessile oak', 'silver fir', 'sycamore maple', 'weymouth pine']
# Time period july-2022: Train shape: (8630, 5, 5, 17), Validation shape: (1850, 5, 5, 17), Test shape: (1850, 5, 5, 17)
# I0000 00:00:1751157214.457117      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751157219.843108      60 service.cc:148] XLA service 0x7f93a80044f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751157219.843623      60 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1751157220.255995      60 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  61/540 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1765 - loss: 3.0117
# I0000 00:00:1751157222.965892      60 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.2376 - loss: 2.5532 - val_accuracy: 0.1730 - val_loss: 2.4300
# Epoch 2/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2900 - loss: 2.2572 - val_accuracy: 0.1876 - val_loss: 3.6922
# Epoch 3/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3143 - loss: 2.1534 - val_accuracy: 0.1265 - val_loss: 4.3923
# Epoch 4/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3248 - loss: 2.0954 - val_accuracy: 0.1816 - val_loss: 2.8325
# Epoch 5/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3403 - loss: 2.0692 - val_accuracy: 0.3259 - val_loss: 2.1615
# Epoch 6/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3479 - loss: 2.0463 - val_accuracy: 0.3070 - val_loss: 2.1784
# Epoch 7/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3523 - loss: 2.0268 - val_accuracy: 0.1135 - val_loss: 2.8442
# Epoch 8/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3574 - loss: 2.0220 - val_accuracy: 0.1319 - val_loss: 4.8957
# Epoch 9/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3784 - loss: 1.9557 - val_accuracy: 0.3124 - val_loss: 2.2355
# Epoch 10/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3822 - loss: 1.9433 - val_accuracy: 0.1859 - val_loss: 2.7915
# Epoch 11/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3747 - loss: 1.9228 - val_accuracy: 0.0854 - val_loss: 4.9885
# Epoch 12/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3914 - loss: 1.9052 - val_accuracy: 0.3043 - val_loss: 2.5093
# Epoch 13/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3899 - loss: 1.9054 - val_accuracy: 0.3508 - val_loss: 2.1716
# Epoch 14/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4064 - loss: 1.8560 - val_accuracy: 0.2389 - val_loss: 2.3979
# Epoch 15/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4127 - loss: 1.8232 - val_accuracy: 0.3416 - val_loss: 2.0298
# Epoch 16/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4055 - loss: 1.8440 - val_accuracy: 0.3038 - val_loss: 2.3456
# Epoch 17/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4235 - loss: 1.7959 - val_accuracy: 0.3335 - val_loss: 2.0235
# Epoch 18/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4221 - loss: 1.7891 - val_accuracy: 0.2454 - val_loss: 2.7890
# Epoch 19/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4290 - loss: 1.7671 - val_accuracy: 0.2892 - val_loss: 2.1297
# Epoch 20/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4320 - loss: 1.7610 - val_accuracy: 0.3238 - val_loss: 2.1888
# Epoch 21/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4487 - loss: 1.7404 - val_accuracy: 0.2973 - val_loss: 2.2515
# Epoch 22/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4446 - loss: 1.7022 - val_accuracy: 0.1989 - val_loss: 3.5638
# Epoch 23/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4514 - loss: 1.7131 - val_accuracy: 0.3524 - val_loss: 2.0417
# Epoch 24/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4619 - loss: 1.6974 - val_accuracy: 0.1795 - val_loss: 4.0163
# Epoch 25/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4615 - loss: 1.6671 - val_accuracy: 0.1849 - val_loss: 3.0388
# Epoch 26/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4623 - loss: 1.6936 - val_accuracy: 0.2373 - val_loss: 3.1965
# Epoch 27/50
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4748 - loss: 1.6396 - val_accuracy: 0.1535 - val_loss: 4.7441
# Time period july-2022: Test Accuracy: 0.3308, Test Loss: 2.0003
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Time period july-2022: Classification Report:
#                 precision    recall  f1-score   support
#
#          alder       0.00      0.00      0.00        77
#          birch       0.15      0.12      0.14       131
#     black pine       0.12      0.62      0.20        34
#         cherry       0.00      0.00      0.00         8
#    douglas fir       0.88      0.34      0.49       188
#    english oak       0.30      0.62      0.40       177
#   european ash       0.21      0.07      0.11        57
# european beech       0.29      0.73      0.42       120
# european larch       0.22      0.06      0.09        35
# japanese larch       0.23      0.11      0.15       128
#         linden       0.00      0.00      0.00         7
#  norway spruce       0.25      0.83      0.38       101
#         poplar       0.00      0.00      0.00        11
#        red oak       0.75      0.05      0.09       124
#     scots pine       0.61      0.43      0.51       423
#    sessile oak       1.00      0.01      0.02        87
#     silver fir       0.42      0.22      0.29        65
# sycamore maple       0.00      0.00      0.00        35
#  weymouth pine       0.07      0.10      0.08        42
#
#       accuracy                           0.33      1850
#      macro avg       0.29      0.23      0.18      1850
#   weighted avg       0.44      0.33      0.30      1850
#
#
# Processing time period: august-2022
#
# Inspecting first 2 rows of needleleaf_fir_silver firaugust-2022.geojson:
# Row 0:
#   B1: [[0.11524999886751175, 0.11574999988079071, 0.11574999988079071, 0.11574999988079071, 0.11574999988079071], [0.11524999886751175, 0.11469999700784683, 0.11469999700784683, 0.11469999700784683, 0.11469999700784683], [0.11445000022649765, 0.11469999700784683, 0.11469999700784683, 0.11469999700784683, 0.11469999700784683], [0.11445000022649765, 0.11445000022649765, 0.11469999700784683, 0.11469999700784683, 0.11469999700784683], [0.11445000022649765, 0.11445000022649765, 0.11469999700784683, 0.11469999700784683, 0.11469999700784683]]
#   B2: [[0.11429999768733978, 0.11669999361038208, 0.11669999361038208, 0.1168999969959259, 0.1168999969959259], [0.11515000462532043, 0.11560000479221344, 0.11560000479221344, 0.11480000615119934, 0.11480000615119934], [0.11490000039339066, 0.11630000174045563, 0.11630000174045563, 0.1160999983549118, 0.1160999983549118], [0.11829999834299088, 0.11924999952316284, 0.11744999885559082, 0.11380000412464142, 0.11380000412464142], [0.11924999952316284, 0.11585000157356262, 0.1156499981880188, 0.11444999277591705, 0.11444999277591705]]
#   B3: [[0.12484999746084213, 0.12759999930858612, 0.12759999930858612, 0.12764999270439148, 0.12764999270439148], [0.12549999356269836, 0.1246500015258789, 0.1246500015258789, 0.1225999966263771, 0.1225999966263771], [0.12514999508857727, 0.1269499957561493, 0.1269499957561493, 0.12449999898672104, 0.12449999898672104], [0.1273999959230423, 0.12870000302791595, 0.12755000591278076, 0.1234000027179718, 0.1234000027179718], [0.12870000302791595, 0.124549999833107, 0.12460000067949295, 0.1253499984741211, 0.1253499984741211]]
#   B4: [[0.11315000057220459, 0.1152999997138977, 0.1152999997138977, 0.11464999616146088, 0.11464999616146088], [0.11319999396800995, 0.11315000057220459, 0.11315000057220459, 0.11329999566078186, 0.11329999566078186], [0.11394999921321869, 0.11454999446868896, 0.11454999446868896, 0.11474999785423279, 0.11474999785423279], [0.11425000429153442, 0.11535000056028366, 0.11460000276565552, 0.1132500022649765, 0.1132500022649765], [0.11535000056028366, 0.11415000259876251, 0.1136000007390976, 0.1137000024318695, 0.1137000024318695]]
#   B5: [[0.14354999363422394, 0.14875000715255737, 0.14875000715255737, 0.14875000715255737, 0.14875000715255737], [0.14354999363422394, 0.14544999599456787, 0.14544999599456787, 0.14544999599456787, 0.14544999599456787], [0.14350000023841858, 0.14544999599456787, 0.14544999599456787, 0.14544999599456787, 0.14544999599456787], [0.14350000023841858, 0.147599995136261, 0.14550000429153442, 0.14550000429153442, 0.14550000429153442], [0.147599995136261, 0.147599995136261, 0.14550000429153442, 0.14550000429153442, 0.14550000429153442]]
#   l3_species: silver fir
# Row 1:
#   B1: [[0.11800000071525574, 0.11800000071525574, 0.11800000071525574, 0.11845000088214874, 0.11845000088214874], [0.11800000071525574, 0.11800000071525574, 0.11800000071525574, 0.11845000088214874, 0.11845000088214874], [0.1168999969959259, 0.1168999969959259, 0.1168999969959259, 0.11739999800920486, 0.11739999800920486], [0.1168999969959259, 0.1168999969959259, 0.1168999969959259, 0.11739999800920486, 0.11739999800920486], [0.1168999969959259, 0.1168999969959259, 0.1168999969959259, 0.11739999800920486, 0.11739999800920486]]
#   B2: [[0.11654999852180481, 0.11654999852180481, 0.11474999785423279, 0.11885000020265579, 0.11885000020265579], [0.11945000290870667, 0.11945000290870667, 0.11749999970197678, 0.11869999766349792, 0.11869999766349792], [0.11810000240802765, 0.11810000240802765, 0.11509999632835388, 0.11410000175237656, 0.11410000175237656], [0.11760000139474869, 0.11760000139474869, 0.11699999868869781, 0.11580000072717667, 0.11580000072717667], [0.1145000010728836, 0.1145000010728836, 0.11550000309944153, 0.11659999936819077, 0.11659999936819077]]
#   B3: [[0.1237500011920929, 0.1237500011920929, 0.1221499964594841, 0.12884999811649323, 0.12884999811649323], [0.1302500069141388, 0.1302500069141388, 0.12745000422000885, 0.12939999997615814, 0.12939999997615814], [0.12710000574588776, 0.12710000574588776, 0.12370000034570694, 0.1234000027179718, 0.1234000027179718], [0.13009999692440033, 0.13009999692440033, 0.13040000200271606, 0.1251000016927719, 0.1251000016927719], [0.12710000574588776, 0.12710000574588776, 0.12710000574588776, 0.12700000405311584, 0.12700000405311584]]
#   B4: [[0.1151999980211258, 0.1151999980211258, 0.1148499995470047, 0.11810000240802765, 0.11810000240802765], [0.11814999580383301, 0.11814999580383301, 0.11759999394416809, 0.11739999800920486, 0.11739999800920486], [0.11630000174045563, 0.11630000174045563, 0.11320000141859055, 0.1137000024318695, 0.1137000024318695], [0.11540000140666962, 0.11540000140666962, 0.11500000208616257, 0.11479999870061874, 0.11479999870061874], [0.11379999667406082, 0.11379999667406082, 0.1151999980211258, 0.11540000140666962, 0.11540000140666962]]
#   B5: [[0.14274999499320984, 0.14274999499320984, 0.14274999499320984, 0.1521500051021576, 0.1521500051021576], [0.14274999499320984, 0.14274999499320984, 0.14274999499320984, 0.1521500051021576, 0.1521500051021576], [0.14380000531673431, 0.14380000531673431, 0.14380000531673431, 0.15150000154972076, 0.15150000154972076], [0.14380000531673431, 0.14380000531673431, 0.14380000531673431, 0.15150000154972076, 0.15150000154972076], [0.14380000531673431, 0.14380000531673431, 0.14380000531673431, 0.14839999377727509, 0.14839999377727509]]
#   l3_species: silver fir
# Time period august-2022: Available columns: 17/17
# Time period august-2022: Loaded 37907 valid samples with shape (37907, 5, 5, 17)
# Time period august-2022: Unique labels: ['alder', 'birch', 'black pine', 'cherry', 'douglas fir', 'english oak', 'european ash', 'european beech', 'european larch', 'japanese larch', 'linden', 'norway spruce', 'poplar', 'red oak', 'scots pine', 'sessile oak', 'silver fir', 'sycamore maple', 'weymouth pine']
#
# Time period august-2022: Checking for NaN values...
# Time period august-2022: Normalizing data...
# Time period august-2022: Data range after normalization: min=0.0000, max=1.0000
# Time period august-2022: Data shape: (37907, 5, 5, 17), Number of classes: 19
# Time period august-2022: Class names: ['alder', 'birch', 'black pine', 'cherry', 'douglas fir', 'english oak', 'european ash', 'european beech', 'european larch', 'japanese larch', 'linden', 'norway spruce', 'poplar', 'red oak', 'scots pine', 'sessile oak', 'silver fir', 'sycamore maple', 'weymouth pine']
# Time period august-2022: Train shape: (26533, 5, 5, 17), Validation shape: (5687, 5, 5, 17), Test shape: (5687, 5, 5, 17)
# Epoch 1/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.2970 - loss: 2.3205 - val_accuracy: 0.3293 - val_loss: 2.0967
# Epoch 2/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3754 - loss: 2.0199 - val_accuracy: 0.4299 - val_loss: 1.7983
# Epoch 3/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3983 - loss: 1.9240 - val_accuracy: 0.4252 - val_loss: 1.7735
# Epoch 4/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4046 - loss: 1.8944 - val_accuracy: 0.4243 - val_loss: 1.8038
# Epoch 5/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4251 - loss: 1.8542 - val_accuracy: 0.4196 - val_loss: 1.8660
# Epoch 6/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4191 - loss: 1.8476 - val_accuracy: 0.3772 - val_loss: 2.1261
# Epoch 7/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4291 - loss: 1.8007 - val_accuracy: 0.3339 - val_loss: 2.2498
# Epoch 8/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4431 - loss: 1.7737 - val_accuracy: 0.3392 - val_loss: 2.4623
# Epoch 9/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4416 - loss: 1.7508 - val_accuracy: 0.4600 - val_loss: 1.6968
# Epoch 10/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4573 - loss: 1.7199 - val_accuracy: 0.4287 - val_loss: 1.9286
# Epoch 11/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4679 - loss: 1.6917 - val_accuracy: 0.4153 - val_loss: 1.9188
# Epoch 12/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4727 - loss: 1.6618 - val_accuracy: 0.3293 - val_loss: 2.3698
# Epoch 13/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4874 - loss: 1.6319 - val_accuracy: 0.4751 - val_loss: 1.6900
# Epoch 14/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4873 - loss: 1.6229 - val_accuracy: 0.3786 - val_loss: 2.1333
# Epoch 15/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.4953 - loss: 1.6022 - val_accuracy: 0.4996 - val_loss: 1.5657
# Epoch 16/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4993 - loss: 1.5797 - val_accuracy: 0.2328 - val_loss: 7.1099
# Epoch 17/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5071 - loss: 1.5618 - val_accuracy: 0.4734 - val_loss: 1.6933
# Epoch 18/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5148 - loss: 1.5350 - val_accuracy: 0.4403 - val_loss: 1.7615
# Epoch 19/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5113 - loss: 1.5458 - val_accuracy: 0.4192 - val_loss: 1.9777
# Epoch 20/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5147 - loss: 1.5460 - val_accuracy: 0.5080 - val_loss: 1.5308
# Epoch 21/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5160 - loss: 1.5269 - val_accuracy: 0.4108 - val_loss: 1.9501
# Epoch 22/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5221 - loss: 1.5015 - val_accuracy: 0.4873 - val_loss: 1.5934
# Epoch 23/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5217 - loss: 1.4975 - val_accuracy: 0.4065 - val_loss: 2.1560
# Epoch 24/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5278 - loss: 1.4764 - val_accuracy: 0.5069 - val_loss: 1.5854
# Epoch 25/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5315 - loss: 1.4604 - val_accuracy: 0.4327 - val_loss: 1.9441
# Epoch 26/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5320 - loss: 1.4678 - val_accuracy: 0.4971 - val_loss: 1.5660
# Epoch 27/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5397 - loss: 1.4439 - val_accuracy: 0.5326 - val_loss: 1.4879
# Epoch 28/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5367 - loss: 1.4465 - val_accuracy: 0.4285 - val_loss: 2.2095
# Epoch 29/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5418 - loss: 1.4420 - val_accuracy: 0.4734 - val_loss: 1.7992
# Epoch 30/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5420 - loss: 1.4346 - val_accuracy: 0.3759 - val_loss: 2.4621
# Epoch 31/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5436 - loss: 1.4267 - val_accuracy: 0.4306 - val_loss: 1.8015
# Epoch 32/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5441 - loss: 1.4104 - val_accuracy: 0.4435 - val_loss: 1.8755
# Epoch 33/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5456 - loss: 1.3913 - val_accuracy: 0.4111 - val_loss: 2.1875
# Epoch 34/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5534 - loss: 1.3845 - val_accuracy: 0.5008 - val_loss: 1.6723
# Epoch 35/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5504 - loss: 1.3772 - val_accuracy: 0.5219 - val_loss: 1.5509
# Epoch 36/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5622 - loss: 1.3558 - val_accuracy: 0.4633 - val_loss: 1.7903
# Epoch 37/50
# 1659/1659 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5645 - loss: 1.3569 - val_accuracy: 0.4880 - val_loss: 1.7362
# Time period august-2022: Test Accuracy: 0.5310, Test Loss: 1.4870
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Time period august-2022: Classification Report:
#                 precision    recall  f1-score   support
#
#          alder       0.24      0.10      0.14       322
#          birch       0.31      0.35      0.33       370
#     black pine       0.50      0.08      0.14        62
#         cherry       0.00      0.00      0.00        37
#    douglas fir       0.60      0.57      0.58       328
#    english oak       0.39      0.66      0.49       421
#   european ash       0.51      0.25      0.34       330
# european beech       0.47      0.85      0.61       714
# european larch       0.47      0.19      0.27       171
# japanese larch       0.93      0.33      0.49       242
#         linden       0.00      0.00      0.00        24
#  norway spruce       0.65      0.84      0.73       756
#         poplar       1.00      0.02      0.03        58
#        red oak       0.53      0.43      0.47       219
#     scots pine       0.81      0.75      0.78       808
#    sessile oak       0.42      0.39      0.41       317
#     silver fir       0.41      0.65      0.50       122
# sycamore maple       0.40      0.11      0.17       314
#  weymouth pine       0.92      0.15      0.26        72
#
#       accuracy                           0.53      5687
#      macro avg       0.50      0.35      0.35      5687
#   weighted avg       0.54      0.53      0.50      5687
#
#
# Processing time period: mar-oct-2022
#
# Inspecting first 2 rows of needleleaf_douglas fir_douglas firmar-oct-2022.geojson:
# Row 0:
#   B1: [[0.11180000007152557, 0.11580000072717667, 0.11580000072717667, 0.11580000072717667, 0.11580000072717667], [0.11180000007152557, 0.11180000007152557, 0.11580000072717667, 0.11580000072717667, 0.11580000072717667], [0.11180000007152557, 0.11180000007152557, 0.11580000072717667, 0.11580000072717667, 0.11580000072717667], [0.11180000007152557, 0.11180000007152557, 0.11580000072717667, 0.11580000072717667, 0.11580000072717667], [0.11180000007152557, 0.11180000007152557, 0.11580000072717667, 0.11580000072717667, 0.11580000072717667]]
#   B2: [[0.11225000023841858, 0.11335000395774841, 0.11335000395774841, 0.11955000460147858, 0.11955000460147858], [0.12045000493526459, 0.12045000493526459, 0.12205000221729279, 0.12334999442100525, 0.12334999442100525], [0.12139999866485596, 0.12139999866485596, 0.1237500011920929, 0.12305000424385071, 0.12305000424385071], [0.11665000021457672, 0.11665000021457672, 0.11685000360012054, 0.12019999325275421, 0.12019999325275421], [0.11649999767541885, 0.11649999767541885, 0.11490000039339066, 0.12000000476837158, 0.12000000476837158]]
#   B3: [[0.11829999834299088, 0.11630000174045563, 0.11630000174045563, 0.12144999951124191, 0.12144999951124191], [0.13314999639987946, 0.13314999639987946, 0.12770000100135803, 0.12919999659061432, 0.12919999659061432], [0.13224999606609344, 0.13224999606609344, 0.13214999437332153, 0.13249999284744263, 0.13249999284744263], [0.1261499971151352, 0.1261499971151352, 0.12494999915361404, 0.1289999932050705, 0.1289999932050705], [0.1229500025510788, 0.1229500025510788, 0.12434999644756317, 0.13019999861717224, 0.13019999861717224]]
#   B4: [[0.1156499981880188, 0.1168999969959259, 0.1168999969959259, 0.12540000677108765, 0.12540000677108765], [0.1274999976158142, 0.1274999976158142, 0.12655000388622284, 0.13189999759197235, 0.13189999759197235], [0.12710000574588776, 0.12710000574588776, 0.12485000491142273, 0.1281999945640564, 0.1281999945640564], [0.12129999697208405, 0.12129999697208405, 0.11669999361038208, 0.1270500123500824, 0.1270500123500824], [0.117249995470047, 0.117249995470047, 0.11734999716281891, 0.1281999945640564, 0.1281999945640564]]
#   B5: [[0.13199999928474426, 0.14114999771118164, 0.14114999771118164, 0.14114999771118164, 0.14114999771118164], [0.14419999718666077, 0.14419999718666077, 0.15289999544620514, 0.15289999544620514, 0.15289999544620514], [0.14419999718666077, 0.14419999718666077, 0.15289999544620514, 0.15289999544620514, 0.15289999544620514], [0.13985000550746918, 0.13985000550746918, 0.15275000035762787, 0.15275000035762787, 0.15275000035762787], [0.13985000550746918, 0.13985000550746918, 0.15275000035762787, 0.15275000035762787, 0.15275000035762787]]
#   l3_species: douglas fir
# Row 1:
#   B1: [[0.125, 0.12399999797344208, 0.12399999797344208, 0.12399999797344208, 0.12399999797344208], [0.125, 0.12399999797344208, 0.12399999797344208, 0.12399999797344208, 0.12399999797344208], [0.125, 0.12399999797344208, 0.12399999797344208, 0.12399999797344208, 0.12399999797344208], [0.125, 0.12399999797344208, 0.12399999797344208, 0.12399999797344208, 0.12399999797344208], [0.125, 0.12399999797344208, 0.12399999797344208, 0.12399999797344208, 0.12399999797344208]]
#   B2: [[0.12389999628067017, 0.11760000139474869, 0.11760000139474869, 0.1151999980211258, 0.11699999868869781], [0.12200000137090683, 0.12039999663829803, 0.12039999663829803, 0.11559999734163284, 0.11659999936819077], [0.11840000003576279, 0.11969999969005585, 0.11969999969005585, 0.11559999734163284, 0.11620000004768372], [0.11959999799728394, 0.125, 0.125, 0.12330000102519989, 0.11710000038146973], [0.12470000237226486, 0.1298999935388565, 0.1298999935388565, 0.11980000138282776, 0.12039999663829803]]
#   B3: [[0.1348000019788742, 0.12319999933242798, 0.12319999933242798, 0.12280000001192093, 0.12449999898672104], [0.13289999961853027, 0.1282999962568283, 0.1282999962568283, 0.12049999833106995, 0.12189999967813492], [0.12120000272989273, 0.12620000541210175, 0.12620000541210175, 0.12309999763965607, 0.11580000072717667], [0.1234000027179718, 0.13220000267028809, 0.13220000267028809, 0.12800000607967377, 0.12110000103712082], [0.131400004029274, 0.13500000536441803, 0.13500000536441803, 0.13130000233650208, 0.1289999932050705]]
#   B4: [[0.12919999659061432, 0.12020000070333481, 0.12020000070333481, 0.1152999997138977, 0.11749999970197678], [0.1242000013589859, 0.11969999969005585, 0.11969999969005585, 0.11460000276565552, 0.11699999868869781], [0.12020000070333481, 0.12150000035762787, 0.12150000035762787, 0.11789999902248383, 0.11509999632835388], [0.12559999525547028, 0.12809999287128448, 0.12809999287128448, 0.12139999866485596, 0.11569999903440475], [0.1395999938249588, 0.14100000262260437, 0.14100000262260437, 0.12309999763965607, 0.12200000137090683]]
#   B5: [[0.15440000593662262, 0.14169999957084656, 0.14169999957084656, 0.14169999957084656, 0.13779999315738678], [0.15440000593662262, 0.14169999957084656, 0.14169999957084656, 0.14169999957084656, 0.13779999315738678], [0.15379999577999115, 0.1467999964952469, 0.1467999964952469, 0.1467999964952469, 0.13650000095367432], [0.15379999577999115, 0.1467999964952469, 0.1467999964952469, 0.1467999964952469, 0.13650000095367432], [0.15880000591278076, 0.16019999980926514, 0.16019999980926514, 0.16019999980926514, 0.14489999413490295]]
#   l3_species: douglas fir
# Time period mar-oct-2022: Available columns: 136/136
#
# Time period mar-oct-2022: Skipped 31782 invalid samples
# File: needleleaf_douglas fir_douglas firmar-oct-2022.geojson, Row: 0, Error: Null value for band B1_1
# File: needleleaf_douglas fir_douglas firmar-oct-2022.geojson, Row: 2, Error: Null value for band B1_4
# File: needleleaf_douglas fir_douglas firmar-oct-2022.geojson, Row: 3, Error: Null value for band B1_6
# File: needleleaf_douglas fir_douglas firmar-oct-2022.geojson, Row: 5, Error: Null value for band B1_4
# File: needleleaf_douglas fir_douglas firmar-oct-2022.geojson, Row: 6, Error: Null value for band B1_1
# Time period mar-oct-2022: Loaded 6125 valid samples with shape (6125, 5, 5, 136)
# Time period mar-oct-2022: Unique labels: ['alder', 'birch', 'black pine', 'cherry', 'douglas fir', 'english oak', 'european ash', 'european beech', 'european larch', 'japanese larch', 'linden', 'norway spruce', 'poplar', 'red oak', 'scots pine', 'sessile oak', 'silver fir', 'sycamore maple', 'weymouth pine']
#
# Time period mar-oct-2022: Checking for NaN values...
# Time period mar-oct-2022: Normalizing data...
# Time period mar-oct-2022: Data range after normalization: min=0.0000, max=1.0000
# Time period mar-oct-2022: Data shape: (6125, 5, 5, 136), Number of classes: 19
# Time period mar-oct-2022: Class names: ['alder', 'birch', 'black pine', 'cherry', 'douglas fir', 'english oak', 'european ash', 'european beech', 'european larch', 'japanese larch', 'linden', 'norway spruce', 'poplar', 'red oak', 'scots pine', 'sessile oak', 'silver fir', 'sycamore maple', 'weymouth pine']
# Time period mar-oct-2022: Train shape: (4287, 5, 5, 136), Validation shape: (919, 5, 5, 136), Test shape: (919, 5, 5, 136)
# Epoch 1/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.3041 - loss: 2.4042 - val_accuracy: 0.1045 - val_loss: 2.7065
# Epoch 2/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3982 - loss: 1.9145 - val_accuracy: 0.4059 - val_loss: 1.8422
# Epoch 3/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4581 - loss: 1.7409 - val_accuracy: 0.2557 - val_loss: 2.6996
# Epoch 4/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4850 - loss: 1.6119 - val_accuracy: 0.3297 - val_loss: 2.1988
# Epoch 5/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5027 - loss: 1.5710 - val_accuracy: 0.5005 - val_loss: 1.5874
# Epoch 6/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5346 - loss: 1.4675 - val_accuracy: 0.3776 - val_loss: 2.2319
# Epoch 7/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5404 - loss: 1.4318 - val_accuracy: 0.4853 - val_loss: 1.5244
# Epoch 8/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5564 - loss: 1.3645 - val_accuracy: 0.3526 - val_loss: 2.0196
# Epoch 9/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5706 - loss: 1.3506 - val_accuracy: 0.2992 - val_loss: 2.8293
# Epoch 10/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5758 - loss: 1.3268 - val_accuracy: 0.2350 - val_loss: 3.0038
# Epoch 11/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5859 - loss: 1.2707 - val_accuracy: 0.2307 - val_loss: 4.0359
# Epoch 12/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5923 - loss: 1.2725 - val_accuracy: 0.5332 - val_loss: 1.5106
# Epoch 13/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5979 - loss: 1.2480 - val_accuracy: 0.2089 - val_loss: 3.3075
# Epoch 14/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6082 - loss: 1.2157 - val_accuracy: 0.5071 - val_loss: 1.6420
# Epoch 15/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6263 - loss: 1.1612 - val_accuracy: 0.5343 - val_loss: 1.7620
# Epoch 16/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6396 - loss: 1.1315 - val_accuracy: 0.4940 - val_loss: 2.0619
# Epoch 17/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6381 - loss: 1.1528 - val_accuracy: 0.3047 - val_loss: 2.5533
# Epoch 18/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6457 - loss: 1.1120 - val_accuracy: 0.3634 - val_loss: 2.0246
# Epoch 19/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6497 - loss: 1.0905 - val_accuracy: 0.4091 - val_loss: 2.1299
# Epoch 20/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6585 - loss: 1.0597 - val_accuracy: 0.4178 - val_loss: 1.9801
# Epoch 21/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6695 - loss: 1.0568 - val_accuracy: 0.5887 - val_loss: 1.1856
# Epoch 22/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6615 - loss: 1.0292 - val_accuracy: 0.4276 - val_loss: 2.2134
# Epoch 23/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6762 - loss: 1.0262 - val_accuracy: 0.2209 - val_loss: 3.7544
# Epoch 24/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6788 - loss: 1.0091 - val_accuracy: 0.3613 - val_loss: 2.6414
# Epoch 25/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6885 - loss: 0.9668 - val_accuracy: 0.5190 - val_loss: 1.5930
# Epoch 26/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6879 - loss: 0.9608 - val_accuracy: 0.5005 - val_loss: 1.8470
# Epoch 27/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7039 - loss: 0.9278 - val_accuracy: 0.4842 - val_loss: 1.9173
# Epoch 28/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6959 - loss: 0.9526 - val_accuracy: 0.4527 - val_loss: 1.9986
# Epoch 29/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7233 - loss: 0.8653 - val_accuracy: 0.4951 - val_loss: 1.8442
# Epoch 30/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7147 - loss: 0.9076 - val_accuracy: 0.6137 - val_loss: 1.2919
# Epoch 31/50
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7173 - loss: 0.8613 - val_accuracy: 0.6235 - val_loss: 1.2201
# Time period mar-oct-2022: Test Accuracy: 0.5930, Test Loss: 1.1949
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Time period mar-oct-2022: Classification Report:
#                 precision    recall  f1-score   support
#
#          alder       0.42      0.77      0.55        53
#          birch       0.47      0.38      0.42        55
#     black pine       0.76      0.90      0.82        31
#         cherry       0.00      0.00      0.00         1
#    douglas fir       0.37      0.97      0.54        70
#    english oak       0.53      0.53      0.53       106
#   european ash       0.65      0.31      0.42        36
# european beech       0.65      0.55      0.59        44
# european larch       1.00      0.33      0.50        18
# japanese larch       0.88      0.65      0.75        55
#         linden       1.00      0.33      0.50         6
#  norway spruce       0.75      0.67      0.70        57
#         poplar       1.00      0.14      0.25         7
#        red oak       0.44      0.68      0.53        41
#     scots pine       0.83      0.63      0.71       252
#    sessile oak       0.45      0.15      0.22        34
#     silver fir       0.64      0.37      0.47        19
# sycamore maple       0.00      0.00      0.00        14
#  weymouth pine       0.75      0.75      0.75        20
#
#       accuracy                           0.59       919
#      macro avg       0.61      0.48      0.49       919
#   weighted avg       0.65      0.59      0.59       919
#
#
# Processing time period: all-2022
#
# Inspecting first 2 rows of needleleaf_pine_weymouth pineall-2022.geojson:
# Row 0:
#   B1: None
#   B2: None
#   B3: None
#   B4: None
#   B5: None
#   l3_species: weymouth pine
# Row 1:
#   B1: None
#   B2: None
#   B3: None
#   B4: None
#   B5: None
#   l3_species: weymouth pine
# Time period all-2022: Available columns: 204/204
#
# Time period all-2022: Skipped 31805 invalid samples
# File: needleleaf_pine_weymouth pineall-2022.geojson, Row: 0, Error: Null value for band B1
# File: needleleaf_pine_weymouth pineall-2022.geojson, Row: 1, Error: Null value for band B1
# File: needleleaf_pine_weymouth pineall-2022.geojson, Row: 2, Error: Null value for band B1
# File: needleleaf_pine_weymouth pineall-2022.geojson, Row: 3, Error: Null value for band B1
# File: needleleaf_pine_weymouth pineall-2022.geojson, Row: 4, Error: Null value for band B1
# Time period all-2022: Loaded 2676 valid samples with shape (2676, 5, 5, 204)
# Time period all-2022: Unique labels: ['alder', 'birch', 'black pine', 'cherry', 'douglas fir', 'english oak', 'european ash', 'european beech', 'european larch', 'japanese larch', 'linden', 'norway spruce', 'poplar', 'red oak', 'scots pine', 'sessile oak', 'silver fir', 'sycamore maple']
#
# Time period all-2022: Checking for NaN values...
# Time period all-2022: Normalizing data...
# Time period all-2022: Data range after normalization: min=0.0000, max=1.0000
# Time period all-2022: Data shape: (2676, 5, 5, 204), Number of classes: 18
# Time period all-2022: Class names: ['alder', 'birch', 'black pine', 'cherry', 'douglas fir', 'english oak', 'european ash', 'european beech', 'european larch', 'japanese larch', 'linden', 'norway spruce', 'poplar', 'red oak', 'scots pine', 'sessile oak', 'silver fir', 'sycamore maple']
# Time period all-2022: Train shape: (1872, 5, 5, 204), Validation shape: (402, 5, 5, 204), Test shape: (402, 5, 5, 204)
# Epoch 1/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.3255 - loss: 2.3090 - val_accuracy: 0.3507 - val_loss: 1.9653
# Epoch 2/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5169 - loss: 1.6791 - val_accuracy: 0.5348 - val_loss: 1.5215
# Epoch 3/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5636 - loss: 1.4802 - val_accuracy: 0.5050 - val_loss: 1.8655
# Epoch 4/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5981 - loss: 1.3843 - val_accuracy: 0.2488 - val_loss: 3.0961
# Epoch 5/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6414 - loss: 1.2630 - val_accuracy: 0.4801 - val_loss: 1.9118
# Epoch 6/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6383 - loss: 1.2355 - val_accuracy: 0.4851 - val_loss: 1.7745
# Epoch 7/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6375 - loss: 1.2164 - val_accuracy: 0.2886 - val_loss: 2.7537
# Epoch 8/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6697 - loss: 1.0571 - val_accuracy: 0.4129 - val_loss: 3.2542
# Epoch 9/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6915 - loss: 1.0749 - val_accuracy: 0.3308 - val_loss: 2.0435
# Epoch 10/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6525 - loss: 1.1649 - val_accuracy: 0.6642 - val_loss: 1.2113
# Epoch 11/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7015 - loss: 0.9917 - val_accuracy: 0.3209 - val_loss: 2.5348
# Epoch 12/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7168 - loss: 0.9426 - val_accuracy: 0.6020 - val_loss: 1.3584
# Epoch 13/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7153 - loss: 0.9279 - val_accuracy: 0.4925 - val_loss: 1.9255
# Epoch 14/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7336 - loss: 0.9095 - val_accuracy: 0.1841 - val_loss: 6.1080
# Epoch 15/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7133 - loss: 0.9301 - val_accuracy: 0.6219 - val_loss: 1.3160
# Epoch 16/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7215 - loss: 0.9013 - val_accuracy: 0.6269 - val_loss: 1.3145
# Epoch 17/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7162 - loss: 0.9028 - val_accuracy: 0.3781 - val_loss: 2.5707
# Epoch 18/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7510 - loss: 0.8198 - val_accuracy: 0.5199 - val_loss: 1.9472
# Epoch 19/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7399 - loss: 0.8349 - val_accuracy: 0.7289 - val_loss: 0.9587
# Epoch 20/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7630 - loss: 0.7770 - val_accuracy: 0.5846 - val_loss: 1.7772
# Epoch 21/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7696 - loss: 0.7325 - val_accuracy: 0.4851 - val_loss: 2.0876
# Epoch 22/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7658 - loss: 0.7729 - val_accuracy: 0.6244 - val_loss: 1.5659
# Epoch 23/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7671 - loss: 0.7074 - val_accuracy: 0.6318 - val_loss: 1.4428
# Epoch 24/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7632 - loss: 0.7135 - val_accuracy: 0.6891 - val_loss: 1.1399
# Epoch 25/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7783 - loss: 0.7125 - val_accuracy: 0.3756 - val_loss: 3.0132
# Epoch 26/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7731 - loss: 0.7197 - val_accuracy: 0.4328 - val_loss: 2.6730
# Epoch 27/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8051 - loss: 0.6236 - val_accuracy: 0.6194 - val_loss: 1.3550
# Epoch 28/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7811 - loss: 0.6695 - val_accuracy: 0.5373 - val_loss: 1.9441
# Epoch 29/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7861 - loss: 0.6691 - val_accuracy: 0.6642 - val_loss: 1.3621
# Time period all-2022: Test Accuracy: 0.6791, Test Loss: 1.1476
# Error evaluating model for time period all-2022: Number of classes, 17, does not match size of target_names, 18. Try specifying the labels parameter
#
# Summary of Results:
#
# Time Period july-2022:
#   Test Accuracy: 0.3308
#   Test Loss: 2.0003
#   Weighted Precision: 0.4430
#   Weighted Recall: 0.3308
#   Weighted F1-Score: 0.3000
#   Macro Precision: 0.2898
#   Macro Recall: 0.2268
#   Macro F1-Score: 0.1771
#   Number of Classes: 19
#   Class Names: ['alder', 'birch', 'black pine', 'cherry', 'douglas fir', 'english oak', 'european ash', 'european beech', 'european larch', 'japanese larch', 'linden', 'norway spruce', 'poplar', 'red oak', 'scots pine', 'sessile oak', 'silver fir', 'sycamore maple', 'weymouth pine']
#
# Time Period august-2022:
#   Test Accuracy: 0.5310
#   Test Loss: 1.4870
#   Weighted Precision: 0.5428
#   Weighted Recall: 0.5310
#   Weighted F1-Score: 0.4982
#   Macro Precision: 0.5030
#   Macro Recall: 0.3536
#   Macro F1-Score: 0.3549
#   Number of Classes: 19
#   Class Names: ['alder', 'birch', 'black pine', 'cherry', 'douglas fir', 'english oak', 'european ash', 'european beech', 'european larch', 'japanese larch', 'linden', 'norway spruce', 'poplar', 'red oak', 'scots pine', 'sessile oak', 'silver fir', 'sycamore maple', 'weymouth pine']
#
# Time Period mar-oct-2022:
#   Test Accuracy: 0.5930
#   Test Loss: 1.1949
#   Weighted Precision: 0.6502
#   Weighted Recall: 0.5930
#   Weighted F1-Score: 0.5886
#   Macro Precision: 0.6094
#   Macro Recall: 0.4798
#   Macro F1-Score: 0.4871
#   Number of Classes: 19
#   Class Names: ['alder', 'birch', 'black pine', 'cherry', 'douglas fir', 'english oak', 'european ash', 'european beech', 'european larch', 'japanese larch', 'linden', 'norway spruce', 'poplar', 'red oak', 'scots pine', 'sessile oak', 'silver fir', 'sycamore maple', 'weymouth pine']

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import layers, models
import geopandas as gpd
import ast
import os
import json
import joblib
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# 1. Define Parameters
time_period = 'all-2022'
patch_size = 5  # Fixed to 5x5 based on GEE code
data_folder = '/kaggle/input/all2022'  # Update with actual path

# Define bands
base_bands = [
    'B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12',
    'NDVI', 'EVI', 'SAVI', 'NDWI', 'DEM'
]
time_period_config = {
    'all-2022': {
        'months': ['', '_1', '_2', '_3', '_4', '_5', '_6', '_7', '_8', '_9', '_10', '_11'],
        'num_bands': 204  # 17 bands × 12 months
    }
}

# 2. Function to Load Data
def load_data(folder_path):
    all_features = []
    all_labels = []
    invalid_samples = []
    # Get band columns
    band_columns = [band + month for month in time_period_config[time_period]['months'] for band in base_bands]
    # Verify available columns
    available_columns = None
    for file in os.listdir(folder_path):
        if file.endswith(".geojson"):
            gdf = gpd.read_file(os.path.join(folder_path, file))
            available_columns = [col for col in band_columns if col in gdf.columns]
            # Debugging: Print sample data for first few rows
            print(f"\nInspecting first 2 rows of {file}:")
            for idx in range(min(2, len(gdf))):
                print(f"Row {idx}:")
                for col in available_columns[:5]:  # Print first 5 bands
                    print(f"  {col}: {gdf[col].iloc[idx]}")
                print(f"  l3_species: {gdf['l3_species'].iloc[idx]}")
            break
    if not available_columns:
        raise ValueError(f"No valid GeoJSON files found in {folder_path}")
    print(f"Available columns: {len(available_columns)}/{len(band_columns)}")
    expected_shape = (patch_size, patch_size, len(available_columns))

    # Load all GeoJSON files
    for file in os.listdir(folder_path):
        if file.endswith(".geojson"):
            gdf = gpd.read_file(os.path.join(folder_path, file))
            for idx, row in gdf.iterrows():
                try:
                    if row['l3_species'] is None or not isinstance(row['l3_species'], str):
                        raise ValueError(f"Invalid label at row {idx}: {row['l3_species']}")
                    patches = []
                    for col in available_columns:
                        val = row[col]
                        if val is None:
                            raise ValueError(f"Null value for band {col}")
                        if isinstance(val, (list, np.ndarray)):
                            arr = np.array(val, dtype=np.float32).reshape(patch_size, patch_size)
                        elif isinstance(val, str):
                            try:
                                arr = np.array(json.loads(val), dtype=np.float32).reshape(patch_size, patch_size)
                            except json.JSONDecodeError:
                                arr = np.array(ast.literal_eval(val), dtype=np.float32).reshape(patch_size, patch_size)
                        elif isinstance(val, (float, np.float32, np.float64)):
                            arr = np.full((patch_size, patch_size), val, dtype=np.float32)
                        else:
                            raise ValueError(f"Unexpected data type for band {col}: {type(val)}")
                        patches.append(arr)

                    patch = np.stack(patches, axis=-1)
                    if patch.shape != expected_shape:
                        raise ValueError(f"Unexpected patch shape: {patch.shape}, expected {expected_shape}")
                    all_features.append(patch)
                    all_labels.append(row['l3_species'])
                except Exception as e:
                    invalid_samples.append((file, idx, str(e)))
                    continue

    if invalid_samples:
        print(f"\nSkipped {len(invalid_samples)} invalid samples")
        for file, idx, error in invalid_samples[:5]:
            print(f"File: {file}, Row: {idx}, Error: {error}")
        with open('invalid_samples_all-2022.json', 'w') as f:
            json.dump(invalid_samples, f, indent=4)

    if not all_features:
        raise ValueError("No valid samples loaded. Check GeoJSON files.")
    X = np.array(all_features, dtype=np.float32)
    y = np.array(all_labels)
    print(f"Loaded {len(all_features)} valid samples with shape {X.shape}")
    print(f"Unique labels: {np.unique(y).tolist()}")
    print(f"Label distribution: {dict(Counter(y))}")
    return X, y, invalid_samples, available_columns

# 3. Define CNN Model
def build_cnn(input_shape, num_classes):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

# 4. Data Augmentation
def get_data_augmentation():
    return tf.keras.Sequential([
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(0.2),
    ])

# 5. Main Processing
print(f"\nProcessing time period: {time_period}")
if not os.path.exists(data_folder):
    raise ValueError(f"Folder {data_folder} does not exist.")

# Load data
try:
    X, y, invalid_samples, available_columns = load_data(data_folder)
except Exception as e:
    raise ValueError(f"Error loading data: {e}")

# Handle NaN values
print("\nChecking for NaN values...")
nan_mask = np.any(np.isnan(X), axis=(1, 2, 3))
nan_count = np.sum(nan_mask)
if nan_count > 0:
    print(f"Removing {nan_count} samples with NaN values")
    valid_mask = ~nan_mask
    X = X[valid_mask]
    y = y[valid_mask]
    print(f"New data shape after removing NaN: {X.shape}")

# Normalize data
print("Normalizing data...")
X_min = np.nanmin(X, axis=(0, 1, 2), keepdims=True)
X_max = np.nanmax(X, axis=(0, 1, 2), keepdims=True)
X = (X - X_min) / (X_max - X_min + 1e-6)
print(f"Data range after normalization: min={np.nanmin(X):.4f}, max={np.nanmax(X):.4f}")

# Encode labels
try:
    label_encoder = LabelEncoder()
    y_encoded = label_encoder.fit_transform(y)
    y_onehot = tf.keras.utils.to_categorical(y_encoded)
    num_classes = len(label_encoder.classes_)
    print(f"Data shape: {X.shape}, Number of classes: {num_classes}")
    print(f"Class names: {label_encoder.classes_.tolist()}")
except Exception as e:
    raise ValueError(f"Error encoding labels: {e}")

# Train-test-validation split
try:
    X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.15, random_state=42, stratify=y_onehot)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1765, random_state=42, stratify=y_train)
    print(f"Train shape: {X_train.shape}, Validation shape: {X_val.shape}, Test shape: {X_test.shape}")
except Exception as e:
    raise ValueError(f"Error splitting data: {e}")

# Build and compile model
try:
    model = build_cnn(input_shape=(patch_size, patch_size, len(available_columns)), num_classes=num_classes)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
except Exception as e:
    raise ValueError(f"Error building model: {e}")

# Train model
try:
    history = model.fit(
        get_data_augmentation()(X_train), y_train,
        validation_data=(X_val, y_val),
        epochs=50,
        batch_size=16,
        callbacks=[
            tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
            tf.keras.callbacks.ModelCheckpoint('best_model_all-2022.keras', save_best_only=True)
        ],
        verbose=1
    )
except Exception as e:
    raise ValueError(f"Error training model: {e}")

# Evaluate model
try:
    test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f"Test Accuracy: {test_accuracy:.4f}, Test Loss: {test_loss:.4f}")

    # Compute additional metrics
    y_pred = model.predict(X_test, verbose=0)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_test_classes = np.argmax(y_test, axis=1)

    # Classification report with explicit labels
    labels = np.arange(len(label_encoder.classes_))
    class_report = classification_report(y_test_classes, y_pred_classes, labels=labels, target_names=label_encoder.classes_, output_dict=True)
    print(f"\nClassification Report:")
    print(classification_report(y_test_classes, y_pred_classes, labels=labels, target_names=label_encoder.classes_))

    # Confusion matrix
    cm = confusion_matrix(y_test_classes, y_pred_classes, labels=labels)
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix: all-2022')
    plt.savefig('confusion_matrix_all-2022.png')
    plt.close()

    # Store results
    results = {
        'time_period': time_period,
        'test_accuracy': test_accuracy,
        'test_loss': test_loss,
        'classification_report': class_report,
        'history': history.history,
        'num_classes': num_classes,
        'class_names': label_encoder.classes_.tolist()
    }
except Exception as e:
    raise ValueError(f"Error evaluating model: {e}")

# 6. Save Results
print("\nSummary of Results:")
print(f"Test Accuracy: {results['test_accuracy']:.4f}")
print(f"Test Loss: {results['test_loss']:.4f}")
print(f"Weighted Precision: {results['classification_report']['weighted avg']['precision']:.4f}")
print(f"Weighted Recall: {results['classification_report']['weighted avg']['recall']:.4f}")
print(f"Weighted F1-Score: {results['classification_report']['weighted avg']['f1-score']:.4f}")
print(f"Macro Precision: {results['classification_report']['macro avg']['precision']:.4f}")
print(f"Macro Recall: {results['classification_report']['macro avg']['recall']:.4f}")
print(f"Macro F1-Score: {results['classification_report']['macro avg']['f1-score']:.4f}")
print(f"Number of Classes: {results['num_classes']}")
print(f"Class Names: {results['class_names']}")

joblib.dump(label_encoder, 'label_encoder_all-2022.pkl')
with open('results_summary_all-2022.json', 'w') as f:
    json.dump({k: v for k, v in results.items() if k != 'history'}, f, indent=4)
# Out:
# Processing time period: all-2022
#
# Inspecting first 2 rows of needleleaf_pine_weymouth pineall-2022.geojson:
# Row 0:
#   B1: None
#   B2: None
#   B3: None
#   B4: None
#   B5: None
#   l3_species: weymouth pine
# Row 1:
#   B1: None
#   B2: None
#   B3: None
#   B4: None
#   B5: None
#   l3_species: weymouth pine
# Available columns: 204/204
#
# Skipped 31805 invalid samples
# File: needleleaf_pine_weymouth pineall-2022.geojson, Row: 0, Error: Null value for band B1
# File: needleleaf_pine_weymouth pineall-2022.geojson, Row: 1, Error: Null value for band B1
# File: needleleaf_pine_weymouth pineall-2022.geojson, Row: 2, Error: Null value for band B1
# File: needleleaf_pine_weymouth pineall-2022.geojson, Row: 3, Error: Null value for band B1
# File: needleleaf_pine_weymouth pineall-2022.geojson, Row: 4, Error: Null value for band B1
# Loaded 2676 valid samples with shape (2676, 5, 5, 204)
# Unique labels: ['alder', 'birch', 'black pine', 'cherry', 'douglas fir', 'english oak', 'european ash', 'european beech', 'european larch', 'japanese larch', 'linden', 'norway spruce', 'poplar', 'red oak', 'scots pine', 'sessile oak', 'silver fir', 'sycamore maple']
# Label distribution: {'linden': 36, 'douglas fir': 220, 'english oak': 361, 'silver fir': 9, 'european ash': 116, 'scots pine': 774, 'black pine': 2, 'european beech': 149, 'poplar': 15, 'birch': 112, 'european larch': 84, 'sycamore maple': 50, 'sessile oak': 114, 'norway spruce': 238, 'cherry': 6, 'red oak': 85, 'japanese larch': 96, 'alder': 209}
#
# Checking for NaN values...
# Normalizing data...
# Data range after normalization: min=0.0000, max=1.0000
# Data shape: (2676, 5, 5, 204), Number of classes: 18
# Class names: ['alder', 'birch', 'black pine', 'cherry', 'douglas fir', 'english oak', 'european ash', 'european beech', 'european larch', 'japanese larch', 'linden', 'norway spruce', 'poplar', 'red oak', 'scots pine', 'sessile oak', 'silver fir', 'sycamore maple']
# Train shape: (1872, 5, 5, 204), Validation shape: (402, 5, 5, 204), Test shape: (402, 5, 5, 204)
# Epoch 1/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.3537 - loss: 2.2596 - val_accuracy: 0.3483 - val_loss: 2.1197
# Epoch 2/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4955 - loss: 1.6537 - val_accuracy: 0.1493 - val_loss: 3.9788
# Epoch 3/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5664 - loss: 1.4396 - val_accuracy: 0.5100 - val_loss: 1.5249
# Epoch 4/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5740 - loss: 1.4039 - val_accuracy: 0.2363 - val_loss: 2.4557
# Epoch 5/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6338 - loss: 1.2439 - val_accuracy: 0.2065 - val_loss: 2.5224
# Epoch 6/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6603 - loss: 1.1833 - val_accuracy: 0.6045 - val_loss: 1.3849
# Epoch 7/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6406 - loss: 1.2231 - val_accuracy: 0.6119 - val_loss: 1.3452
# Epoch 8/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6729 - loss: 1.0835 - val_accuracy: 0.3358 - val_loss: 3.0600
# Epoch 9/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6997 - loss: 1.0322 - val_accuracy: 0.5050 - val_loss: 1.5884
# Epoch 10/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6713 - loss: 1.0591 - val_accuracy: 0.2587 - val_loss: 4.9007
# Epoch 11/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6885 - loss: 1.0346 - val_accuracy: 0.5398 - val_loss: 1.9653
# Epoch 12/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7364 - loss: 0.9150 - val_accuracy: 0.4826 - val_loss: 2.2284
# Epoch 13/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6997 - loss: 0.9446 - val_accuracy: 0.6866 - val_loss: 1.0266
# Epoch 14/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7101 - loss: 0.9403 - val_accuracy: 0.6318 - val_loss: 1.2801
# Epoch 15/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7200 - loss: 0.9346 - val_accuracy: 0.3259 - val_loss: 4.1732
# Epoch 16/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7303 - loss: 0.9184 - val_accuracy: 0.6119 - val_loss: 1.4906
# Epoch 17/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7534 - loss: 0.8696 - val_accuracy: 0.6493 - val_loss: 1.3180
# Epoch 18/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7460 - loss: 0.8893 - val_accuracy: 0.3308 - val_loss: 3.0699
# Epoch 19/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7225 - loss: 0.8786 - val_accuracy: 0.5746 - val_loss: 1.6524
# Epoch 20/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7441 - loss: 0.8273 - val_accuracy: 0.6095 - val_loss: 1.5121
# Epoch 21/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7778 - loss: 0.7642 - val_accuracy: 0.5498 - val_loss: 1.4676
# Epoch 22/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7753 - loss: 0.7851 - val_accuracy: 0.7512 - val_loss: 0.9256
# Epoch 23/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7924 - loss: 0.7054 - val_accuracy: 0.6119 - val_loss: 1.3574
# Epoch 24/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7796 - loss: 0.7255 - val_accuracy: 0.5473 - val_loss: 1.5477
# Epoch 25/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7742 - loss: 0.7202 - val_accuracy: 0.6493 - val_loss: 1.4452
# Epoch 26/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7867 - loss: 0.6918 - val_accuracy: 0.5821 - val_loss: 2.4106
# Epoch 27/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7649 - loss: 0.7554 - val_accuracy: 0.6965 - val_loss: 1.2733
# Epoch 28/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7944 - loss: 0.6525 - val_accuracy: 0.5697 - val_loss: 1.5937
# Epoch 29/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8015 - loss: 0.6496 - val_accuracy: 0.5995 - val_loss: 1.5376
# Epoch 30/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8050 - loss: 0.6467 - val_accuracy: 0.5622 - val_loss: 1.8539
# Epoch 31/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7990 - loss: 0.6370 - val_accuracy: 0.4502 - val_loss: 2.3379
# Epoch 32/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8159 - loss: 0.6176 - val_accuracy: 0.7488 - val_loss: 0.9702
# Test Accuracy: 0.7338, Test Loss: 0.9294
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#                 precision    recall  f1-score   support
#
#          alder       0.77      0.87      0.82        31
#          birch       0.12      0.06      0.08        17
#     black pine       0.00      0.00      0.00         0
#         cherry       0.00      0.00      0.00         1
#    douglas fir       0.94      0.94      0.94        33
#    english oak       0.74      0.80      0.77        54
#   european ash       0.61      0.94      0.74        18
# european beech       0.59      0.77      0.67        22
# european larch       0.44      0.62      0.52        13
# japanese larch       0.67      0.53      0.59        15
#         linden       0.60      0.60      0.60         5
#  norway spruce       0.78      0.50      0.61        36
#         poplar       0.00      0.00      0.00         2
#        red oak       1.00      0.08      0.14        13
#     scots pine       0.85      0.96      0.90       116
#    sessile oak       0.53      0.47      0.50        17
#     silver fir       0.00      0.00      0.00         1
# sycamore maple       0.33      0.25      0.29         8
#
#      micro avg       0.73      0.73      0.73       402
#      macro avg       0.50      0.47      0.45       402
#   weighted avg       0.72      0.73      0.71       402
#
#
# Summary of Results:
# Test Accuracy: 0.7338
# Test Loss: 0.9294
# Weighted Precision: 0.7236
# Weighted Recall: 0.7338
# Weighted F1-Score: 0.7080
# Macro Precision: 0.4988
# Macro Recall: 0.4659
# Macro F1-Score: 0.4532
# Number of Classes: 18
# Class Names: ['alder', 'birch', 'black pine', 'cherry', 'douglas fir', 'english oak', 'european ash', 'european beech', 'european larch', 'japanese larch', 'linden', 'norway spruce', 'poplar', 'red oak', 'scots pine', 'sessile oak', 'silver fir', 'sycamore maple']
